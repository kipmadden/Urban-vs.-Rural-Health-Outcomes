# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/2019 County Health Rankings Texas Data - v1_0.xls")
xls = pd.ExcelFile("data/2019 County Health Rankings Texas Data - v1_0.xls")
xls.sheet_names
# Out:
# ['Introduction',
#  'Outcomes & Factors Rankings',
#  'Outcomes & Factors SubRankings',
#  'Ranked Measure Data',
#  'Additional Measure Data',
#  'Ranked Measure Sources & Years',
#  'Addtl Measure Sources & Years']

# %%
df1 = pd.read_excel(xls, 'Outcomes & Factors Rankings', header=[0,1])
df1.columns = df1.columns.map('_'.join)
df2 = pd.read_excel(xls, 'Outcomes & Factors SubRankings', header=[0,1])
df2.columns = df2.columns.map('_'.join)
df3 = pd.read_excel(xls, 'Ranked Measure Data', header=[0,1])
df3.columns = df3.columns.map('_'.join)
df4 = pd.read_excel(xls, 'Additional Measure Data', header=[0,1])
df4.columns = df4.columns.map('_'.join)

# %%
df4.head()
# Out:
#    Unnamed: 0_level_0_FIPS Unnamed: 1_level_0_State Unnamed: 2_level_0_County  \
# 0                    48000                    Texas                       NaN
# 1                    48001                    Texas                  Anderson
# 2                    48003                    Texas                   Andrews
# 3                    48005                    Texas                  Angelina
# 4                    48007                    Texas                   Aransas
#
#    Life expectancy_Life Expectancy  Life expectancy_95% CI - Low  \
# 0                        79.021563                     78.985226
# 1                        73.773772                     73.075431
# 2                        76.756795                     75.377601
# 3                        76.336820                     75.722123
# 4                        76.912561                     75.793952
#
#    Life expectancy_95% CI - High  Life expectancy_Life Expectancy (Black)  \
# ...

# %%
#Merge the worksheets to a single DF
main_df=df4.merge(df3)
#Saving data to csv
main_df.to_csv("../output_data/df3_df4.csv")
main_df.head()
# Out:
#    Unnamed: 0_level_0_FIPS Unnamed: 1_level_0_State Unnamed: 2_level_0_County  \
# 0                    48000                    Texas                       NaN
# 1                    48001                    Texas                  Anderson
# 2                    48003                    Texas                   Andrews
# 3                    48005                    Texas                  Angelina
# 4                    48007                    Texas                   Aransas
#
#    Life expectancy_Life Expectancy  Life expectancy_95% CI - Low  \
# 0                        79.021563                     78.985226
# 1                        73.773772                     73.075431
# 2                        76.756795                     75.377601
# 3                        76.336820                     75.722123
# 4                        76.912561                     75.793952
#
#    Life expectancy_95% CI - High  Life expectancy_Life Expectancy (Black)  \
# ...

# %%
work_df=main_df[[
'Unnamed: 0_level_0_FIPS',
'Unnamed: 1_level_0_State',
'Unnamed: 2_level_0_County',
'Life expectancy_Life Expectancy',
'Premature age-adjusted mortality_Age-Adjusted Mortality',
'Child mortality_Child Mortality Rate',
'Infant mortality_Infant Mortality Rate',
'Frequent physical distress_% Frequent Physical Distress',
'Frequent mental distress_% Frequent Mental Distress',
'Diabetes prevalence_% Diabetic',
'HIV prevalence_HIV Prevalence Rate',
'Food insecurity_% Food Insecure',
'Limited access to healthy foods_% Limited Access',
'Drug overdose deaths_Drug Overdose Mortality Rate',
'Motor vehicle crash deaths_MV Mortality Rate',
'Insufficient sleep_% Insufficient Sleep',
'Uninsured adults_% Uninsured',
'Uninsured children_% Uninsured',
'Disconnected youth_% Disconnected Youth',
'Median household income_Household Income',
'Median household income_Household income (Black)',
'Median household income_Household income (Hispanic)',
'Median household income_Household income (White)',
'Children eligible for free or reduced price lunch_% Free or Reduced Lunch',
'Residential segregation - black/white_Segregation index',
'Residential segregation - non-white/white_Segregation Index',
'Homicides_Homicide Rate',
'Firearm fatalities_Firearm Fatalities Rate',
'Homeownership_% Homeowners',
'Severe housing cost burden_# Households with Severe Cost Burden',
'Demographics_Population',
'Demographics_% < 18',
'Demographics_% 65 and over',
'Demographics_% African American',
'Demographics_% American Indian/Alaskan Native',
'Demographics_% Asian',
'Demographics_% Native Hawaiian/Other Pacific Islander',
'Demographics_% Hispanic',
'Demographics_% Non-Hispanic White',
'Demographics_% Not Proficient in English',
'Demographics_% Female',
'Demographics_% Rural',
'Premature death_Years of Potential Life Lost Rate',
'Premature death_YPLL Rate (Black)',
'Premature death_YPLL Rate (Hispanic)',
'Premature death_YPLL Rate (White)',
'Poor or fair health_% Fair/Poor',
'Poor physical health days_Physically Unhealthy Days',
'Poor mental health days_Mentally Unhealthy Days',
'Low birthweight_% LBW',
'Low birthweight_% LBW (Black)',
'Low birthweight_% LBW (Hispanic)',
'Low birthweight_% LBW (White)',
'Adult smoking_% Smokers',
'Adult obesity_% Obese',
'Food environment index_Food Environment Index',
'Physical inactivity_% Physically Inactive',
'Access to exercise opportunities_% With Access',
'Excessive drinking_% Excessive Drinking',
'Alcohol-impaired driving deaths_# Alcohol-Impaired Driving Deaths',
'Alcohol-impaired driving deaths_# Driving Deaths',
'Alcohol-impaired driving deaths_% Alcohol-Impaired',
'Sexually transmitted infections_# Chlamydia Cases',
'Sexually transmitted infections_Chlamydia Rate',
'Teen births_Teen Birth Rate',
'Teen births_Teen Birth Rate (Black)',
'Teen births_Teen Birth Rate (Hispanic)',
'Teen births_Teen Birth Rate (White)',
'Uninsured_# Uninsured',
'Uninsured_% Uninsured',
'Primary care physicians_# Primary Care Physicians',
'Primary care physicians_PCP Rate',
'Primary care physicians_PCP Ratio',
'Dentists_# Dentists',
'Dentists_Dentist Rate',
'Dentists_Dentist Ratio',
'Mental health providers_# Mental Health Providers',
'Mental health providers_MHP Rate',
'Mental health providers_MHP Ratio',
'Preventable hospital stays_Preventable Hosp. Rate',
'Preventable hospital stays_Preventable Hosp. Rate (Black)',
'Preventable hospital stays_Preventable Hosp. Rate (Hispanic)',
'Preventable hospital stays_Preventable Hosp. Rate (White)',
'Mammography screening_% Screened',
'Mammography screening_% Screened (Black)',
'Mammography screening_% Screened (Hispanic)',
'Mammography screening_% Screened (White)',
'Flu vaccinations_% Vaccinated',
'Flu vaccinations_% Vaccinated (Black)',
'Flu vaccinations_% Vaccinated (Hispanic)',
'Flu vaccinations_% Vaccinated (White)',
'High school graduation_Cohort Size',
'High school graduation_Graduation Rate',
'Some college_# Some College',
'Some college_Population',
'Some college_% Some College',
'Unemployment_# Unemployed',
'Unemployment_Labor Force',
'Unemployment_% Unemployed',
'Children in poverty_% Children in Poverty',
'Children in poverty_% Children in Poverty (Black)',
'Children in poverty_% Children in Poverty (Hispanic)',
'Children in poverty_% Children in Poverty (White)',
'Income inequality_80th Percentile Income',
'Income inequality_20th Percentile Income',
'Income inequality_Income Ratio',
'Children in single-parent households_# Single-Parent Households',
'Children in single-parent households_# Households',
'Children in single-parent households_% Single-Parent Households',
'Social associations_# Associations',
'Social associations_Association Rate',
'Violent crime_Annual Average Violent Crimes',
'Violent crime_Violent Crime Rate',
'Injury deaths_# Injury Deaths',
'Injury deaths_Injury Death Rate',
'Air pollution - particulate matter_Average Daily PM2.5',
'Drinking water violations_Presence of violation',
'Severe housing problems_% Severe Housing Problems',
'Severe housing problems_Severe Housing Cost Burden',
'Severe housing problems_Overcrowding',
'Severe housing problems_Inadequate Facilities',
'Driving alone to work_% Drive Alone',
'Driving alone to work_% Drive Alone (Black)',
'Driving alone to work_% Drive Alone (Hispanic)',
'Driving alone to work_% Drive Alone (White)',
'Long commute - driving alone_# Workers who Drive Alone',
'Long commute - driving alone_% Long Commute - Drives Alone',
]]

work_df.head()
# Out:
#    Unnamed: 0_level_0_FIPS Unnamed: 1_level_0_State Unnamed: 2_level_0_County  \
# 0                    48000                    Texas                       NaN
# 1                    48001                    Texas                  Anderson
# 2                    48003                    Texas                   Andrews
# 3                    48005                    Texas                  Angelina
# 4                    48007                    Texas                   Aransas
#
#    Life expectancy_Life Expectancy  \
# 0                        79.021563
# 1                        73.773772
# 2                        76.756795
# 3                        76.336820
# 4                        76.912561
#
#    Premature age-adjusted mortality_Age-Adjusted Mortality  \
# 0                                              341.1
# 1                                              544.0
# 2                                              398.9
# 3                                              454.5
# ...

# %%
work_final=work_df.rename(columns={"Unnamed: 0_level_0_FIPS": "fips","Unnamed: 1_level_0_State": "state", "Unnamed: 2_level_0_County": "county", "Life expectancy_Life Expectancy": "lifeExpect", "Premature age-adjusted mortality_Age-Adjusted Mortality": "prematureAAMortalityNum",
"Child mortality_Child Mortality Rate": "childMortalityRate", "Infant mortality_Infant Mortality Rate": "infantMortalityRate",
"Frequent physical distress_% Frequent Physical Distress": "freqPhysDistressPerct", "Frequent mental distress_% Frequent Mental Distress": "freqMentalDistressPerct",
"Diabetes prevalence_% Diabetic": "diabeticPerct", "HIV prevalence_HIV Prevalence Rate": "HIVprevRate", "Food insecurity_% Food Insecure": "foodInsecurePerct",
"Limited access to healthy foods_% Limited Access": "foodLimitedAccessPerct", "Drug overdose deaths_Drug Overdose Mortality Rate": "drugODRate",
"Motor vehicle crash deaths_MV Mortality Rate": "MVmortalityRate", "Insufficient sleep_% Insufficient Sleep": "insufficientSleepPerct",
"Uninsured adults_% Uninsured": "adultUninsuredPerct", "Uninsured children_% Uninsured": "childUinsuredPerct", "Disconnected youth_% Disconnected Youth": "disconYouthPerct",
"Median household income_Household Income": "householdIncome", "Median household income_Household income (Black)": "householdIncomeBlack",
"Median household income_Household income (Hispanic)": "householdIncomeHisp", "Median household income_Household income (White)": "householdIncomeWHite",
"Children eligible for free or reduced price lunch_% Free or Reduced Lunch": "childrenFreeLunchPerct", "Residential segregation - black/white_Segregation index": "residentialBlackWhiteSeg", "Residential segregation - non-white/white_Segregation Index": "nonwhiteWhiteSegIdx",
"Homicides_Homicide Rate": "homicideRate", "Firearm fatalities_Firearm Fatalities Rate": "firearmFatalitiesRate", "Homeownership_% Homeowners": "homeownershipPerct",
"Severe housing cost burden_# Households with Severe Cost Burden": "severeHousingCostBurdenPerct", "Demographics_Population": "pop",
"Demographics_% < 18": "popUnder18", "Demographics_% 65 and over": "popOver65Perct", "Demographics_% African American": "popBlackPerct",
"Demographics_% American Indian/Alaskan Native": "popNativePerct", "Demographics_% Asian": "popAsianPerct",
"Demographics_% Native Hawaiian/Other Pacific Islander": "popHawaiinIslanderPerct", "Demographics_% Hispanic": "popHispPerct",
"Demographics_% Non-Hispanic White": "popNonHispWhitePerct", "Demographics_% Not Proficient in English": "popNoEnglishPerct",
"Demographics_% Female": "popFemalePerct", "Demographics_% Rural": "popRuralPerct", "Premature death_Years of Potential Life Lost Rate": "yPLL",
"Premature death_YPLL Rate (Black)": "yPLLBlack", "Premature death_YPLL Rate (Hispanic)": "yPLLHisp", "Premature death_YPLL Rate (White)": "yPLLWhite",
"Poor or fair health_% Fair/Poor": "fairPoorHealthPerct", "Poor physical health days_Physically Unhealthy Days": "physUnhealthDaysAvgNum",
"Poor mental health days_Mentally Unhealthy Days": "mentalHealthDaysAvgNum", "Low birthweight_% LBW": "lowBirthWeightPerct",
"Low birthweight_% LBW (Black)": "lowBirthWeightPerctBlack", "Low birthweight_% LBW (Hispanic)": "lowBirthWeightPerctHisp",
"Low birthweight_% LBW (White)": "lowBirthWeightPerctWhite", "Adult smoking_% Smokers": "smokersPerct", "Adult obesity_% Obese": "obesePerct",
"Food environment index_Food Environment Index": "foodEnvIndex", "Physical inactivity_% Physically Inactive": "physInactivePerct",
"Access to exercise opportunities_% With Access": "exerciseAccessPerct", "Excessive drinking_% Excessive Drinking": "excessDrinkPerct",
"Alcohol-impaired driving deaths_# Alcohol-Impaired Driving Deaths": "alcImpairedDriveDeathNum", "Alcohol-impaired driving deaths_# Driving Deaths": "drivingDeathsNum",
"Alcohol-impaired driving deaths_% Alcohol-Impaired": "alcImpairedDriveDeathPerct", "Sexually transmitted infections_# Chlamydia Cases": "chlamydiaCaseNum",
"Sexually transmitted infections_Chlamydia Rate": "chlamydiaCaseRate", "Teen births_Teen Birth Rate": "teenBirthRate",
"Teen births_Teen Birth Rate (Black)": "teenBirthRateBlack", "Teen births_Teen Birth Rate (Hispanic)": "teenBirthRateHisp",
"Teen births_Teen Birth Rate (White)": "teenBirthRateWhite", "Uninsured_# Uninsured": "uninsuredNum", "Uninsured_% Uninsured": "uninsuredPerct",
"Primary care physicians_# Primary Care Physicians": "primCarePhysNum", "Primary care physicians_PCP Rate": "primCarePhysRate",
"Primary care physicians_PCP Ratio": "primCarePhysRatio", "Dentists_# Dentists": "dentistsNum", "Dentists_Dentist Rate": "dentistsRate",
"Dentists_Dentist Ratio": "dentistsRatio", "Mental health providers_# Mental Health Providers": "mentalHealthProvidNum",
"Mental health providers_MHP Rate": "mentalHealthProvidRate", "Mental health providers_MHP Ratio": "mentalHealthProvidRatio",
"Preventable hospital stays_Preventable Hosp. Rate": "preventableHospStaysNum", "Preventable hospital stays_Preventable Hosp. Rate (Black)": "preventableHospStaysNumBlack",
"Preventable hospital stays_Preventable Hosp. Rate (Hispanic)": "preventableHospStaysNumHisp", "Preventable hospital stays_Preventable Hosp. Rate (White)": "preventableHospStaysNumWhite",
"Mammography screening_% Screened": "mammScreenedPerct", "Mammography screening_% Screened (Black)": "mammScreenedPerctBlack",
"Mammography screening_% Screened (Hispanic)": "mammScreenedPerctHisp", "Mammography screening_% Screened (White)": "mammScreenedPerctWhite",
"Flu vaccinations_% Vaccinated": "fluVaccinatedPerct", "Flu vaccinations_% Vaccinated (Black)": "fluVaccinatedPerctBlack",
"Flu vaccinations_% Vaccinated (Hispanic)": "fluVaccinatedHisp", "Flu vaccinations_% Vaccinated (White)": "fluVaccinatedWhite",
"High school graduation_Cohort Size": "hSchoolGradCohortSize", "High school graduation_Graduation Rate": "hSchoolGradRate",
"Some college_# Some College": "someCollegeNum", "Some college_Population": "someCollegePop", "Some college_% Some College": "someCollegePerct",
"Unemployment_# Unemployed": "unemployedNum", "Unemployment_Labor Force": "laborForceNum", "Unemployment_% Unemployed": "unemployedPerct",
"Children in poverty_% Children in Poverty": "childrenInPovertyPerct", "Children in poverty_% Children in Poverty (Black)": "childrenInPovertyPerctBlack",
"Children in poverty_% Children in Poverty (Hispanic)": "childrenInPovertyPerctHisp", "Children in poverty_% Children in Poverty (White)": "childrenInPovertyPerctWhite",
"Income inequality_80th Percentile Income": "incomeInequalityPerct80Th", "Income inequality_20th Percentile Income": "incomeInequalityPerct20Th",
"Income inequality_Income Ratio": "incomeInequalityRatio", "Children in single-parent households_# Single-Parent Households": "childSingleParentHouseholdsNum",
"Children in single-parent households_# Households": "HouseholdsNum", "Children in single-parent households_% Single-Parent Households": "childSingleParentHouseholdsPerct",
"Social associations_# Associations": "socialAssociationsNum", "Social associations_Association Rate": "socialAssociationsRate",
"Violent crime_Annual Average Violent Crimes": "annAvgViolentCrimes", "Violent crime_Violent Crime Rate": "annAvgViolentCrimesRate",
"Injury deaths_# Injury Deaths": "injuryDeathsNum", "Injury deaths_Injury Death Rate": "injuryDeathsRate",
"Air pollution - particulate matter_Average Daily PM2.5": "airPollutionAvgDailyPM25", "Drinking water violations_Presence of violation": "drinkWaterViolationPresence",
"Severe housing problems_% Severe Housing Problems": "SevereHousingProblemsPerct", "Severe housing problems_Severe Housing Cost Burden": "SevereHousingProblemsCostBurden",
"Severe housing problems_Overcrowding": "SevereHousingProblemsOvercrowding", "Severe housing problems_Inadequate Facilities": "SevereHousingProblemsInadequateFacilities",
"Driving alone to work_% Drive Alone": "driveAlonePerct", "Driving alone to work_% Drive Alone (Black)": "driveAlonePerctBlack",
"Driving alone to work_% Drive Alone (Hispanic)": "driveAlonePerctHisp", "Driving alone to work_% Drive Alone (White)": "driveAlonePerctWhite",
"Long commute - driving alone_# Workers who Drive Alone": "longCommuteWorkersDriveAloneNum", "Long commute - driving alone_% Long Commute - Drives Alone": "longCommuteWorkersDriveAlonePerct"}, errors="raise")

work_final.to_csv("../output_data/work_final.csv")
work_final.head()
# Out:
#     fips  state    county  lifeExpect  prematureAAMortalityNum  \
# 0  48000  Texas       NaN   79.021563                    341.1
# 1  48001  Texas  Anderson   73.773772                    544.0
# 2  48003  Texas   Andrews   76.756795                    398.9
# 3  48005  Texas  Angelina   76.336820                    454.5
# 4  48007  Texas   Aransas   76.912561                    470.0
#
#    childMortalityRate  infantMortalityRate  freqPhysDistressPerct  \
# 0           51.252223             5.721779              10.772883
# 1           46.941011                  NaN              12.117431
# 2                 NaN                  NaN              10.211176
# 3           55.887349             5.491937              13.030222
# 4                 NaN                  NaN              12.065267
#
#    freqMentalDistressPerct  diabeticPerct  ...  SevereHousingProblemsPerct  \
# 0                10.576780            9.7  ...                   17.969559
# ...
