# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import zscore
from scipy.stats import linregress
from scipy.stats import stats
from pprint import pprint
from datetime import datetime
import os
import gmaps
import seaborn as sns
import re

from statsmodels.compat import lzip
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Import API key from a file that is ignored by Git (.gitignore file) so the key isn't exposed to the public
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %% [markdown]
# ## Store County Health Rankings Excel file results into DataFrame
#
# * Load the excel file imported from https://www.countyhealthrankings.org/app/texas/2019/measure/outcomes/144/description?sort=desc-2

# %%
path = "data/2019 County Health Rankings Texas Data - v1_0.xls"

# Get the available sheets in the excel file and put into a list
sheets = pd.ExcelFile(path).sheet_names
print(sheets)
# Out:
# ['Introduction', 'Outcomes & Factors Rankings', 'Outcomes & Factors SubRankings', 'Ranked Measure Data', 'Additional Measure Data', 'Ranked Measure Sources & Years', 'Addtl Measure Sources & Years']

# %% [markdown]
# ## Read in the Ranked Measure Data sheet eliminating columns and extra headers
# * Make a list of available columns to decide what we don't want
# * Formulate a regex expression to match unwanted columns
# * Create a list of only wanted columns to be used for the usecols argument
# * Set county to be the index
# * Eliminate any row without a county name

# %%
# Get the 'Ranked Measure Data' sheet using the sheets list above and rejecting the top header row
rmd = pd.read_excel(path, header=[1], sheet_name=sheets[3])

# View the columns and decide what we don't want
col1 = [col for col in rmd.columns] 
col1.sort()
col1
# Out:
# ['# Alcohol-Impaired Driving Deaths',
#  '# Associations',
#  '# Chlamydia Cases',
#  '# Dentists',
#  '# Driving Deaths',
#  '# Households',
#  '# Injury Deaths',
#  '# Mental Health Providers',
#  '# Primary Care Physicians',
#  '# Single-Parent Households',
#  '# Some College',
#  '# Unemployed',
#  '# Uninsured',
#  '# Workers who Drive Alone',
#  '% Alcohol-Impaired',
#  '% Children in Poverty',
#  '% Children in Poverty (Black)',
#  '% Children in Poverty (Hispanic)',
#  '% Children in Poverty (White)',
#  '% Drive Alone',
#  '% Drive Alone (Black)',
#  '% Drive Alone (Hispanic)',
#  '% Drive Alone (White)',
#  '% Excessive Drinking',
#  '% Fair/Poor',
#  '% LBW',
#  '% LBW (Black)',
#  '% LBW (Hispanic)',
#  '% LBW (White)',
#  '% Long Commute - Drives Alone',
#  '% Obese',
#  '% Physically Inactive',
#  '% Screened',
#  '% Screened (Black)',
#  '% Screened (Hispanic)',
#  '% Screened (White)',
#  '% Severe Housing Problems',
#  '% Single-Parent Households',
#  '% Smokers',
#  '% Some College',
#  '% Unemployed',
#  '% Uninsured',
#  '% Vaccinated',
#  '% Vaccinated (Black)',
#  '% Vaccinated (Hispanic)',
#  '% Vaccinated (White)',
#  '% With Access',
#  '20th Percentile Income',
#  '80th Percentile Income',
#  '95% CI - High',
#  '95% CI - High.1',
#  '95% CI - High.10',
#  '95% CI - High.11',
#  '95% CI - High.12',
#  '95% CI - High.13',
#  '95% CI - High.14',
#  '95% CI - High.15',
#  '95% CI - High.16',
#  '95% CI - High.17',
#  '95% CI - High.18',
#  '95% CI - High.2',
#  '95% CI - High.3',
#  '95% CI - High.4',
#  '95% CI - High.5',
#  '95% CI - High.6',
#  '95% CI - High.7',
#  '95% CI - High.8',
#  '95% CI - High.9',
#  '95% CI - Low',
#  '95% CI - Low.1',
#  '95% CI - Low.10',
#  '95% CI - Low.11',
#  '95% CI - Low.12',
#  '95% CI - Low.13',
#  '95% CI - Low.14',
#  '95% CI - Low.15',
#  '95% CI - Low.16',
#  '95% CI - Low.17',
#  '95% CI - Low.18',
#  '95% CI - Low.2',
#  '95% CI - Low.3',
#  '95% CI - Low.4',
#  '95% CI - Low.5',
#  '95% CI - Low.6',
#  '95% CI - Low.7',
#  '95% CI - Low.8',
#  '95% CI - Low.9',
#  'Annual Average Violent Crimes',
#  'Association Rate',
#  'Average Daily PM2.5',
#  'Chlamydia Rate',
#  'Cohort Size',
#  'County',
#  'Dentist Rate',
#  'Dentist Ratio',
#  'FIPS',
#  'Food Environment Index',
#  'Graduation Rate',
#  'Inadequate Facilities',
#  'Income Ratio',
#  'Injury Death Rate',
#  'Labor Force',
#  'MHP Rate',
#  'MHP Ratio',
#  'Mentally Unhealthy Days',
#  'Overcrowding',
#  'PCP Rate',
#  'PCP Ratio',
#  'Physically Unhealthy Days',
#  'Population',
#  'Presence of violation',
#  'Preventable Hosp. Rate',
#  'Preventable Hosp. Rate (Black)',
#  'Preventable Hosp. Rate (Hispanic)',
#  'Preventable Hosp. Rate (White)',
#  'Severe Housing Cost Burden',
#  'State',
#  'Teen Birth Rate',
#  'Teen Birth Rate (Black)',
#  'Teen Birth Rate (Hispanic)',
#  'Teen Birth Rate (White)',
#  'Unreliable',
#  'Violent Crime Rate',
#  'YPLL Rate (Black)',
#  'YPLL Rate (Hispanic)',
#  'YPLL Rate (White)',
#  'Years of Potential Life Lost Rate',
#  'Z-Score',
#  'Z-Score.1',
#  'Z-Score.10',
#  'Z-Score.11',
#  'Z-Score.12',
#  'Z-Score.13',
#  'Z-Score.14',
#  'Z-Score.15',
#  'Z-Score.16',
#  'Z-Score.17',
#  'Z-Score.18',
#  'Z-Score.19',
#  'Z-Score.2',
#  'Z-Score.20',
#  'Z-Score.21',
#  'Z-Score.22',
#  'Z-Score.23',
#  'Z-Score.24',
#  'Z-Score.25',
#  'Z-Score.26',
#  'Z-Score.27',
#  'Z-Score.28',
#  'Z-Score.29',
#  'Z-Score.3',
#  'Z-Score.30',
#  'Z-Score.31',
#  'Z-Score.32',
#  'Z-Score.33',
#  'Z-Score.34',
#  'Z-Score.4',
#  'Z-Score.5',
#  'Z-Score.6',
#  'Z-Score.7',
#  'Z-Score.8',
#  'Z-Score.9']

# %%
# Create a regular expression to match unwanted columns
regex = '^Z|95|State|Unreliable'

# Use a list comprehension to make a list of columns that don't match the regex (a failed regex match returns 'None')
cols = [col for col in rmd.columns if re.match(regex,col) is None]

# Create a dataframe of the desired columns and set 'County' to the index
rmd_df = pd.read_excel(path, header=[1], sheet_name=sheets[3],usecols=cols)

# Drop any row that has NaN as County value
rmd_df = rmd_df[pd.notnull(rmd_df['County'])]
print(f'shape of rmd_df: {rmd_df.shape}')
rmd_df.head(1)
# Out:
# shape of rmd_df: (254, 87)
#     FIPS    County  Years of Potential Life Lost Rate  YPLL Rate (Black)  \
# 1  48001  Anderson                       10272.949118       12962.159784
#
#    YPLL Rate (Hispanic)  YPLL Rate (White)  % Fair/Poor  \
# 1          10880.315229        9971.540573    19.529585
#
#    Physically Unhealthy Days  Mentally Unhealthy Days     % LBW  ...  \
# 1                    3.92613                 3.642847  7.249879  ...
#
#    % Severe Housing Problems  Severe Housing Cost Burden  Overcrowding  \
# 1                  15.446669                   10.453172       4.30236
#
#    Inadequate Facilities  % Drive Alone  % Drive Alone (Black)  \
# 1               1.224978      85.067105              82.663714
#
#    % Drive Alone (Hispanic)  % Drive Alone (White)  # Workers who Drive Alone  \
# 1                 81.071311              86.307537                      16036
#
#    % Long Commute - Drives Alone
# 1                           26.8
#
# [1 rows x 87 columns]

# %% [markdown]
# ## Read in the Additional Measure Data sheet eliminating columns and extra headers
# * Make a list of available columns to decide what we don't want
# * Formulate a regex expression to match unwanted columns
# * Create a list of only wanted columns to be used for the usecols argument
# * Set county to be the index
# * Eliminate any row without a county name

# %%
# Get the 'Ranked Measure Data' sheet using the sheets list above and rejecting the top header row
amd = pd.read_excel(path, header=[1], sheet_name=sheets[4])

# View the columns and decide what we don't want
[print(col) for col in amd.columns]
# Out:
# FIPS
# State
# County
# Life Expectancy
# 95% CI - Low
# 95% CI - High
# Life Expectancy (Black)
# Life Expectancy (Hispanic)
# Life Expectancy (White)
# # Deaths
# Age-Adjusted Mortality
# 95% CI - Low.1
# 95% CI - High.1
# Age-Adjusted Mortality (Black)
# Age-Adjusted Mortality (Hispanic)
# Age-Adjusted Mortality (White)
# # Deaths.1
# Child Mortality Rate
# 95% CI - Low.2
# 95% CI - High.2
# Child Mortality Rate (Black)
# Child Mortality Rate (Hispanic)
# Child Mortality Rate (White)
# # Deaths.2
# Infant Mortality Rate
# 95% CI - Low.3
# 95% CI - High.3
# Infant Mortality Rate (Black)
# Infant Mortality Rate (Hispanic)
# Infant Mortality Rate (White)
# % Frequent Physical Distress
# 95% CI - Low.4
# 95% CI - High.4
# % Frequent Mental Distress
# 95% CI - Low.5
# 95% CI - High.5
# % Diabetic
# 95% CI - Low.6
# 95% CI - High.6
# # HIV Cases
# HIV Prevalence Rate
# # Food Insecure
# % Food Insecure
# # Limited Access
# % Limited Access
# # Drug Overdose Deaths
# Drug Overdose Mortality Rate
# # Motor Vehicle Deaths
# MV Mortality Rate
# 95% CI - Low.7
# 95% CI - High.7
# % Insufficient Sleep
# 95% CI - Low.8
# 95% CI - High.8
# # Uninsured
# % Uninsured
# 95% CI - Low.9
# 95% CI - High.9
# # Uninsured.1
# % Uninsured.1
# 95% CI - Low.10
# 95% CI - High.10
# Other PCP Rate
# Other PCP Ratio
# % Disconnected Youth
# Household Income
# 95% CI - Low.11
# 95% CI - High.11
# Household income (Black)
# Household income (Hispanic)
# Household income (White)
# % Free or Reduced Lunch
# Segregation index
# Segregation Index
# Homicide Rate
# 95% CI - Low.12
# 95% CI - High.12
# # Firearm Fatalities
# Firearm Fatalities Rate
# 95% CI - Low.13
# 95% CI - High.13
# # Homeowners
# % Homeowners
# 95% CI - Low.14
# 95% CI - High.14
# # Households with Severe Cost Burden
# % Severe Housing Cost Burden
# 95% CI - Low.15
# 95% CI - High.15
# Population
# % < 18
# % 65 and over
# # African American
# % African American
# # American Indian/Alaskan Native
# % American Indian/Alaskan Native
# # Asian
# % Asian
# # Native Hawaiian/Other Pacific Islander
# % Native Hawaiian/Other Pacific Islander
# # Hispanic
# % Hispanic
# # Non-Hispanic White
# % Non-Hispanic White
# # Not Proficient in English
# % Not Proficient in English
# 95% CI - Low.16
# 95% CI - High.16
# % Female
# # Rural
# % Rural
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Create a regular expression to match unwanted columns
regex = '^Z|95|State|Unreliable'

# Use a list comprehension to make a list of columns that don't match the regex (a failed regex match returns 'None')
cols = [col for col in amd.columns if re.match(regex,col) is None]

# Create a dataframe of the desired columns and set 'County' to the index
amd_df = pd.read_excel(path, header=[1], sheet_name=sheets[4],usecols=cols)

# Drop any row that has Nan as County value
amd_df = amd_df[pd.notnull(amd_df['County'])]
print(f'shape of rmd_df: {amd_df.shape}')
amd_df.head(1)
# Out:
# shape of rmd_df: (254, 76)
#     FIPS    County  Life Expectancy  Life Expectancy (Black)  \
# 1  48001  Anderson        73.773772                70.933226
#
#    Life Expectancy (Hispanic)  Life Expectancy (White)  # Deaths  \
# 1                   82.901506                74.097055    1075.0
#
#    Age-Adjusted Mortality  Age-Adjusted Mortality (Black)  \
# 1                   544.0                      721.905041
#
#    Age-Adjusted Mortality (Hispanic)  ...  \
# 1                         597.224357  ...
#
#    % Native Hawaiian/Other Pacific Islander  # Hispanic  % Hispanic  \
# 1                                  0.143745       10287   17.815763
#
#    # Non-Hispanic White  % Non-Hispanic White  # Not Proficient in English  \
# 1                 34140             59.126098                         1488
#
#    % Not Proficient in English  % Female  # Rural    % Rural
# 1                     2.715874  39.06756    39204  67.063533
#
# [1 rows x 76 columns]

# %%
# Merge the rmd and amd dataframes using inner join on County column (index)
merged_df = pd.merge(rmd_df,amd_df, how='inner', on='County')
print(f'shape of merged_df: {merged_df.shape}')
#merged_df.head(1)
# Out:
# shape of merged_df: (254, 162)

# %%
# View the columns that end in '_x' or '_y'
regex2 = '.*_x$|.*_y$'
[print(col) for col in merged_df.columns if re.match(regex2,col) is not None]
# Out:
# FIPS_x
# # Uninsured_x
# % Uninsured_x
# Population_x
# FIPS_y
# # Uninsured_y
# % Uninsured_y
# Population_y
# [None, None, None, None, None, None, None, None]

# %%
# Drop the duplicate _y columns
regex3 = '.*_y$'
merged_df.drop([col for col in merged_df.columns if re.match(regex3,col) is not None],axis=1, inplace=True)
print(merged_df.shape)
# Out:
# (254, 158)

# %%
# Rename the columns to eliminate the '_x' leftover from the join
merged_df.rename(columns = {'FIPS_x':'FIPS',\
                                        '# Uninsured_x':'# Uninsured',\
                                        '% Uninsured_x':'% Uninsured',\
                                        'Population_x':'Population'},\
                                         inplace=True)
#merged_df.columns
# View the columns that end in '_x' or '_y'
regex2 = '.*_x$|.*_y$'
[print(col) for col in merged_df.columns if re.match(regex2,col) is not None]
# Out:
# []

# %% [markdown]
# ## Store NCHS Urban Rural Classification System Excel file results into DataFrame
#
# * Load the excel file imported from https://www.cdc.gov/nchs/data_access/urban_rural.htm#Data_Files_and_Documentation
# * No description or label was given in the 'NCHS URCS' - only numbers 1-6. Reading the file documentation gave this information, so an excel sheet was created and a VLOOKUP mapped the names and descriptions to the classification numbers. The result excel file will be imported and joined to the merged_df

# %%
path2 = 'data/NCHS Urban Rural Classification System.xlsx'

# Get the available sheets in the excel file and put into a list
sheets2 = pd.ExcelFile(path2).sheet_names
print(sheets2)
# Out:
# ['URCS', 'Legend']

# %%
# Get the 'URCS' sheet using the sheets list above and rejecting the top header row
cs = pd.read_excel(path2)
cs.columns
cs.head(1)
# Out:
#    FIPS code State Abr.       County name             CBSA title  \
# 0       1073         AL  Jefferson County  Birmingham-Hoover, AL
#
#   CBSA 2012 pop County 2012 pop  2013 code  2006 code 1990-based code   URCS  \
# 0       1136650          660009          1          1               3  Urban
#
#              URCS Name                                   URCS description
# 0  Large central metro  NCHS-defined "central" counties of MSAs of 1 m...

# %%
# Get the 'URCS' sheet using the columns list above
urcs = pd.read_excel(path2,usecols=['FIPS code','URCS','URCS Name','URCS description'],index_col=0)
print(f'shape of urcs: {urcs.shape}')
# Out:
# shape of urcs: (3149, 3)

# %%
# Drop any row that has Nan as an index value
urcs = urcs.loc[urcs.index.dropna()]
print(f'shape of urcs: {urcs.shape}')
# Out:
# shape of urcs: (3149, 3)

# %%
# Check that all FIPS in the merged_df are in the urcs.index (urcs index has ALL counties in USA not just Texas)
print(f"merged_df FIPS:{[mips for mips in merged_df['FIPS'] if mips not in urcs.index]} not found in urcs.index")
#print(f'urcs county:{[county for county in urcs.index if county not in merged_df["FIPS"]]} not found in merged_df.index')
# Out:
# merged_df FIPS:[] not found in urcs.index

# %%
# Rename the index 'FIPS code' to FIPS
urcs.rename_axis('FIPS', axis=0, inplace=True)
urcs.head()
# Out:
#        URCS            URCS Name  \
# FIPS
# 1073  Urban  Large central metro
# 4013  Urban  Large central metro
# 6001  Urban  Large central metro
# 6037  Urban  Large central metro
# 6059  Urban  Large central metro
#
#                                        URCS description
# FIPS
# 1073  NCHS-defined "central" counties of MSAs of 1 m...
# 4013  NCHS-defined "central" counties of MSAs of 1 m...
# 6001  NCHS-defined "central" counties of MSAs of 1 m...
# 6037  NCHS-defined "central" counties of MSAs of 1 m...
# 6059  NCHS-defined "central" counties of MSAs of 1 m...

# %% [markdown]
# # Merge the NCHS URCS data with the merged_df

# %%
all_df = pd.merge(urcs,merged_df, how='inner', on='FIPS')
#print(all_df.shape)
all_df.head(1)
# Out:
#     FIPS   URCS            URCS Name  \
# 0  48029  Urban  Large central metro
#
#                                     URCS description County  \
# 0  NCHS-defined "central" counties of MSAs of 1 m...  Bexar
#
#    Years of Potential Life Lost Rate  YPLL Rate (Black)  YPLL Rate (Hispanic)  \
# 0                        6930.930981        9500.237875           6729.699925
#
#    YPLL Rate (White)  % Fair/Poor  ...  \
# 0         6981.54228    23.789874  ...
#
#    % Native Hawaiian/Other Pacific Islander  # Hispanic  % Hispanic  \
# 0                                  0.221691     1181315   60.314933
#
#    # Non-Hispanic White  % Non-Hispanic White  # Not Proficient in English  \
# 0                543068             27.727668                       104033
#
#    % Not Proficient in English   % Female  # Rural   % Rural
# 0                     5.926969  50.634542    77835  4.539085
#
# [1 rows x 161 columns]

# %%
multi_df = all_df.set_index(['URCS','URCS Name','County'])
multi_df = multi_df.sort_index()

print(multi_df.shape)
multi_df.head(50)
# Out:
# (254, 158)
#                                  FIPS  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson     48001
#                    Andrews      48003
#                    Angelina     48005
#                    Bee          48025
#                    Brown        48049
#                    Calhoun      48057
#                    Cherokee     48073
#                    Cooke        48097
#                    Dawson       48115
#                    Deaf Smith   48117
#                    Erath        48143
#                    Gillespie    48171
#                    Glasscock    48173
#                    Gray         48179
#                    Hale         48189
#                    Harrison     48203
#                    Henderson    48213
#                    Hockley      48219
#                    Hopkins      48223
#                    Howard       48227
#                    Hutchinson   48233
#                    Jim Wells    48249
#                    Kenedy       48261
#                    Kerr         48265
#                    Kleberg      48273
#                    Lamar        48277
#                    Matagorda    48321
#                    Maverick     48323
#                    Moore        48341
#                    Nacogdoches  48347
#                    Navarro      48349
#                    Nolan        48353
#                    Palo Pinto   48363
#                    Reeves       48389
#                    Scurry       48415
#                    Starr        48427
#                    Titus        48449
#                    Trinity      48455
#                    Uvalde       48463
#                    Val Verde    48465
#                    Walker       48471
#                    Washington   48477
#                    Wharton      48481
#                    Wilbarger    48487
#                    Willacy      48489
#                    Zapata       48505
#       Noncore      Bailey       48017
#                    Baylor       48023
#                    Blanco       48031
#                    Borden       48033
#
#                                                                  URCS description  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson            Counties in micropolitan statistical areas
#                    Andrews             Counties in micropolitan statistical areas
#                    Angelina            Counties in micropolitan statistical areas
#                    Bee                 Counties in micropolitan statistical areas
#                    Brown               Counties in micropolitan statistical areas
#                    Calhoun             Counties in micropolitan statistical areas
#                    Cherokee            Counties in micropolitan statistical areas
#                    Cooke               Counties in micropolitan statistical areas
#                    Dawson              Counties in micropolitan statistical areas
#                    Deaf Smith          Counties in micropolitan statistical areas
#                    Erath               Counties in micropolitan statistical areas
#                    Gillespie           Counties in micropolitan statistical areas
#                    Glasscock           Counties in micropolitan statistical areas
#                    Gray                Counties in micropolitan statistical areas
#                    Hale                Counties in micropolitan statistical areas
#                    Harrison            Counties in micropolitan statistical areas
#                    Henderson           Counties in micropolitan statistical areas
#                    Hockley             Counties in micropolitan statistical areas
#                    Hopkins             Counties in micropolitan statistical areas
#                    Howard              Counties in micropolitan statistical areas
#                    Hutchinson          Counties in micropolitan statistical areas
#                    Jim Wells           Counties in micropolitan statistical areas
#                    Kenedy              Counties in micropolitan statistical areas
#                    Kerr                Counties in micropolitan statistical areas
#                    Kleberg             Counties in micropolitan statistical areas
#                    Lamar               Counties in micropolitan statistical areas
#                    Matagorda           Counties in micropolitan statistical areas
#                    Maverick            Counties in micropolitan statistical areas
#                    Moore               Counties in micropolitan statistical areas
#                    Nacogdoches         Counties in micropolitan statistical areas
#                    Navarro             Counties in micropolitan statistical areas
#                    Nolan               Counties in micropolitan statistical areas
#                    Palo Pinto          Counties in micropolitan statistical areas
#                    Reeves              Counties in micropolitan statistical areas
#                    Scurry              Counties in micropolitan statistical areas
#                    Starr               Counties in micropolitan statistical areas
#                    Titus               Counties in micropolitan statistical areas
#                    Trinity             Counties in micropolitan statistical areas
#                    Uvalde              Counties in micropolitan statistical areas
#                    Val Verde           Counties in micropolitan statistical areas
#                    Walker              Counties in micropolitan statistical areas
#                    Washington          Counties in micropolitan statistical areas
#                    Wharton             Counties in micropolitan statistical areas
#                    Wilbarger           Counties in micropolitan statistical areas
#                    Willacy             Counties in micropolitan statistical areas
#                    Zapata              Counties in micropolitan statistical areas
#       Noncore      Bailey       Counties not within micropolitan statistical a...
#                    Baylor       Counties not within micropolitan statistical a...
#                    Blanco       Counties not within micropolitan statistical a...
#                    Borden       Counties not within micropolitan statistical a...
#
#                                 Years of Potential Life Lost Rate  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson                          10272.949118
#                    Andrews                            7952.973251
#                    Angelina                           9018.498513
#                    Bee                                8026.941398
#                    Brown                             10125.065713
#                    Calhoun                            7019.542448
#                    Cherokee                           9531.886043
#                    Cooke                              7681.512733
#                    Dawson                             8869.732891
#                    Deaf Smith                         7194.472707
#                    Erath                              6923.797693
#                    Gillespie                          6522.124983
#                    Glasscock                                  NaN
#                    Gray                               9702.512031
#                    Hale                               7921.925641
#                    Harrison                           8951.319455
#                    Henderson                         10992.426100
#                    Hockley                            9370.740754
#                    Hopkins                            7840.528348
#                    Howard                             9585.901387
#                    Hutchinson                        10051.736087
#                    Jim Wells                          9280.599666
#                    Kenedy                                     NaN
#                    Kerr                               7951.006013
#                    Kleberg                            8917.254116
#                    Lamar                             10052.762182
#                    Matagorda                          9972.069467
#                    Maverick                           6561.923735
#                    Moore                              7706.119633
#                    Nacogdoches                        7888.324379
#                    Navarro                           10222.636267
#                    Nolan                              9655.197867
#                    Palo Pinto                         9671.590604
#                    Reeves                             8723.582692
#                    Scurry                             7921.134921
#                    Starr                              6280.333912
#                    Titus                              7547.850451
#                    Trinity                           12336.059601
#                    Uvalde                             7528.733005
#                    Val Verde                          6401.268441
#                    Walker                             7109.834292
#                    Washington                         6296.303040
#                    Wharton                            8353.294088
#                    Wilbarger                          8612.806216
#                    Willacy                            7233.883443
#                    Zapata                             6770.768596
#       Noncore      Bailey                             8326.013329
#                    Baylor                            10617.916861
#                    Blanco                             7255.844572
#                    Borden                                     NaN
#
#                                 YPLL Rate (Black)  YPLL Rate (Hispanic)  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson          12962.159784          10880.315229
#                    Andrews                    NaN           7774.144329
#                    Angelina          14014.161619           4450.704830
#                    Bee                        NaN           9362.277052
#                    Brown             14450.701670           8482.889993
#                    Calhoun                    NaN           5363.006364
#                    Cherokee          10744.720335           6046.882812
#                    Cooke                      NaN           4006.687194
#                    Dawson                     NaN           9586.215120
#                    Deaf Smith                 NaN           6763.439447
#                    Erath                      NaN           5791.265468
#                    Gillespie                  NaN           5503.345882
#                    Glasscock                  NaN                   NaN
#                    Gray                       NaN           5430.559158
#                    Hale              12392.488980           8128.033100
#                    Harrison          12543.877437           3402.411594
#                    Henderson         15049.527819           4699.583354
#                    Hockley                    NaN           9295.456616
#                    Hopkins            8910.783284           5822.876371
#                    Howard             5472.553020           8630.644459
#                    Hutchinson                 NaN           8910.602168
#                    Jim Wells                  NaN           9378.403682
#                    Kenedy                     NaN                   NaN
#                    Kerr                       NaN           5993.998233
#                    Kleberg                    NaN           8473.173648
#                    Lamar             13855.737598                   NaN
#                    Matagorda         14031.148087           7776.337370
#                    Maverick                   NaN           6352.373907
#                    Moore                      NaN           5717.427621
#                    Nacogdoches       10438.388176           4363.639378
#                    Navarro           15414.815622           4751.603687
#                    Nolan                      NaN           8415.656323
#                    Palo Pinto                 NaN           7850.248970
#                    Reeves                     NaN           8326.240056
#                    Scurry                     NaN           6481.788046
#                    Starr                      NaN                   NaN
#                    Titus             15592.468732           3796.961703
#                    Trinity           20916.447714                   NaN
#                    Uvalde                     NaN           7308.988708
#                    Val Verde                  NaN           6332.261456
#                    Walker             8131.157182           6536.141258
#                    Washington        10861.126280           5714.911649
#                    Wharton           14842.461096           8138.326623
#                    Wilbarger                  NaN           4011.879938
#                    Willacy                    NaN           6936.394832
#                    Zapata                     NaN                   NaN
#       Noncore      Bailey                     NaN           7370.998705
#                    Baylor                     NaN                   NaN
#                    Blanco                     NaN                   NaN
#                    Borden                     NaN                   NaN
#
#                                 YPLL Rate (White)  % Fair/Poor  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson           9971.540573    19.529585
#                    Andrews            8202.896838    17.307710
#                    Angelina           9293.129659    23.207340
#                    Bee                6933.424902    22.989980
#                    Brown             10399.726006    18.929354
#                    Calhoun            8502.379448    19.456617
#                    Cherokee          10263.168627    20.550797
#                    Cooke              8857.005759    14.983860
#                    Dawson             7288.255881    23.368390
#                    Deaf Smith         8800.110131    24.232103
#                    Erath              7201.716826    19.908742
#                    Gillespie          6938.513736    15.907073
#                    Glasscock                  NaN    16.505721
#                    Gray              11784.459293    18.923391
#                    Hale               7055.536231    25.832052
#                    Harrison           9007.847126    17.912786
#                    Henderson         11580.783622    17.927300
#                    Hockley            9921.000159    20.058446
#                    Hopkins            7957.466062    17.947426
#                    Howard            10838.382692    19.980150
#                    Hutchinson        10279.432667    17.244046
#                    Jim Wells          9760.266799    26.702873
#                    Kenedy                     NaN    26.744554
#                    Kerr               8846.966149    17.722549
#                    Kleberg           11291.406283    27.560405
#                    Lamar             10044.540808    21.132095
#                    Matagorda         11187.505381    22.892415
#                    Maverick           7522.860960    34.910555
#                    Moore              9433.605014    22.387291
#                    Nacogdoches        8291.385345    18.561674
#                    Navarro           10970.166523    19.741818
#                    Nolan             10751.582284    20.505231
#                    Palo Pinto        10194.384139    18.545843
#                    Reeves            11108.024792    25.518154
#                    Scurry             9099.742144    18.385449
#                    Starr                      NaN    40.732355
#                    Titus              8871.598682    22.988692
#                    Trinity           12482.950168    19.309395
#                    Uvalde             7835.520659    27.726145
#                    Val Verde          6696.759301    28.101707
#                    Walker             7209.001680    19.481269
#                    Washington         5362.931720    16.692508
#                    Wharton            6500.633670    21.739277
#                    Wilbarger         10738.874985    19.954136
#                    Willacy            9757.507829    37.762319
#                    Zapata                     NaN    35.437794
#       Noncore      Bailey            12900.396823    27.307111
#                    Baylor                     NaN    16.437425
#                    Blanco                     NaN    15.380683
#                    Borden                     NaN    11.659079
#
#                                 Physically Unhealthy Days  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson                      3.926130
#                    Andrews                       3.302811
#                    Angelina                      4.223947
#                    Bee                           3.914522
#                    Brown                         3.873111
#                    Calhoun                       3.657169
#                    Cherokee                      4.023728
#                    Cooke                         3.437181
#                    Dawson                        3.965460
#                    Deaf Smith                    4.040650
#                    Erath                         4.031431
#                    Gillespie                     3.464866
#                    Glasscock                     3.322088
#                    Gray                          3.748675
#                    Hale                          4.234469
#                    Harrison                      3.747814
#                    Henderson                     3.978474
#                    Hockley                       3.843779
#                    Hopkins                       3.854986
#                    Howard                        3.767979
#                    Hutchinson                    3.662037
#                    Jim Wells                     4.216049
#                    Kenedy                        4.277778
#                    Kerr                          3.795611
#                    Kleberg                       4.350428
#                    Lamar                         4.074431
#                    Matagorda                     4.080666
#                    Maverick                      4.831184
#                    Moore                         3.955761
#                    Nacogdoches                   3.929339
#                    Navarro                       3.982987
#                    Nolan                         3.883677
#                    Palo Pinto                    3.928912
#                    Reeves                        3.918431
#                    Scurry                        3.647759
#                    Starr                         5.505851
#                    Titus                         4.105384
#                    Trinity                       4.107355
#                    Uvalde                        4.399913
#                    Val Verde                     4.237335
#                    Walker                        3.948835
#                    Washington                    3.551472
#                    Wharton                       4.019711
#                    Wilbarger                     3.870720
#                    Willacy                       5.285719
#                    Zapata                        5.003501
#       Noncore      Bailey                        4.516392
#                    Baylor                        3.682539
#                    Blanco                        3.360158
#                    Borden                        2.846577
#
#                                 Mentally Unhealthy Days      % LBW  ...  \
# URCS  URCS Name    County                                           ...
# Rural Micropolitan Anderson                    3.642847   7.249879  ...
#                    Andrews                     3.198057   6.313835  ...
#                    Angelina                    4.070546   8.769194  ...
#                    Bee                         3.469487   9.670165  ...
#                    Brown                       3.733654   9.059712  ...
#                    Calhoun                     3.525164   7.445759  ...
#                    Cherokee                    3.885279   7.680579  ...
#                    Cooke                       3.516380   6.526316  ...
#                    Dawson                      3.561111   9.483423  ...
#                    Deaf Smith                  3.616902   7.747368  ...
#                    Erath                       3.926417   6.971295  ...
#                    Gillespie                   3.531354   7.775872  ...
#                    Glasscock                   3.284666        NaN  ...
#                    Gray                        3.660644   7.070261  ...
#                    Hale                        3.711714   9.695372  ...
#                    Harrison                    3.611280   7.744681  ...
#                    Henderson                   3.847401   7.286673  ...
#                    Hockley                     3.603619   9.119639  ...
#                    Hopkins                     3.745733   7.614852  ...
#                    Howard                      3.541069   9.816713  ...
#                    Hutchinson                  3.710538   9.017561  ...
#                    Jim Wells                   3.684883  10.338559  ...
#                    Kenedy                      3.753374        NaN  ...
#                    Kerr                        3.630272   7.933022  ...
#                    Kleberg                     3.739870   7.742947  ...
#                    Lamar                       4.101579   9.421842  ...
#                    Matagorda                   3.772886   9.141642  ...
#                    Maverick                    3.925119   7.760187  ...
#                    Moore                       3.571740   7.527248  ...
#                    Nacogdoches                 3.881457   7.824648  ...
#                    Navarro                     3.839553   8.464206  ...
#                    Nolan                       3.682472   8.543417  ...
#                    Palo Pinto                  3.820126   7.807571  ...
#                    Reeves                      3.359747   8.987053  ...
#                    Scurry                      3.458854   9.206717  ...
#                    Starr                       4.337911   8.649766  ...
#                    Titus                       3.848757   7.456387  ...
#                    Trinity                     4.019670   7.438017  ...
#                    Uvalde                      3.852181   7.503556  ...
#                    Val Verde                   3.659935   6.619229  ...
#                    Walker                      3.650872   7.861850  ...
#                    Washington                  3.509493   7.944915  ...
#                    Wharton                     3.750063   9.428130  ...
#                    Wilbarger                   3.718834   7.692308  ...
#                    Willacy                     3.958675   8.537170  ...
#                    Zapata                      4.093434   9.006211  ...
#       Noncore      Bailey                      3.968838   7.198228  ...
#                    Baylor                      3.731401  10.408922  ...
#                    Blanco                      3.507162   6.646059  ...
#                    Borden                      3.059777        NaN  ...
#
#                                 % Native Hawaiian/Other Pacific Islander  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson                                     0.143745
#                    Andrews                                      0.022571
#                    Angelina                                     0.063778
#                    Bee                                          0.110555
#                    Brown                                        0.076209
#                    Calhoun                                      0.059787
#                    Cherokee                                     0.053599
#                    Cooke                                        0.052638
#                    Dawson                                       0.132678
#                    Deaf Smith                                   0.084944
#                    Erath                                        0.085778
#                    Gillespie                                    0.142611
#                    Glasscock                                    0.148368
#                    Gray                                         0.004463
#                    Hale                                         0.117185
#                    Harrison                                     0.127511
#                    Henderson                                    0.102388
#                    Hockley                                      0.047644
#                    Hopkins                                      0.109601
#                    Howard                                       0.077691
#                    Hutchinson                                   0.084211
#                    Jim Wells                                    0.080742
#                    Kenedy                                       0.000000
#                    Kerr                                         0.104408
#                    Kleberg                                      0.176917
#                    Lamar                                        0.048400
#                    Matagorda                                    0.119435
#                    Maverick                                     0.034355
#                    Moore                                        0.221750
#                    Nacogdoches                                  0.051845
#                    Navarro                                      1.242274
#                    Nolan                                        0.081246
#                    Palo Pinto                                   0.098005
#                    Reeves                                       0.071985
#                    Scurry                                       0.046921
#                    Starr                                        0.020169
#                    Titus                                        0.176270
#                    Trinity                                      0.047726
#                    Uvalde                                       0.092142
#                    Val Verde                                    0.166650
#                    Walker                                       0.102429
#                    Washington                                   0.048512
#                    Wharton                                      0.050038
#                    Wilbarger                                    0.086180
#                    Willacy                                      0.060230
#                    Zapata                                       0.006982
#       Noncore      Bailey                                       0.127173
#                    Baylor                                       0.083775
#                    Blanco                                       0.094616
#                    Borden                                       0.000000
#
#                                 # Hispanic  % Hispanic  # Non-Hispanic White  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson          10287   17.815763                 34140
#                    Andrews            9958   56.190046                  7131
#                    Angelina          19475   22.179830                 53264
#                    Bee               19238   59.079323                 10161
#                    Brown              8505   22.350406                 27239
#                    Calhoun           10603   48.762877                  9221
#                    Cherokee          12163   23.282925                 31616
#                    Cooke              7242   18.152651                 30050
#                    Dawson             7358   57.426052                  4528
#                    Deaf Smith        13762   73.062221                  4657
#                    Erath              8966   21.363387                 31304
#                    Gillespie          6270   23.530736                 19871
#                    Glasscock           501   37.166172                   815
#                    Gray               6477   28.910016                 14169
#                    Hale              20278   59.407043                 11588
#                    Harrison           8991   13.487646                 42223
#                    Henderson         10458   12.900918                 63338
#                    Hockley           11103   48.089917                 10757
#                    Hopkins            6174   16.916922                 26754
#                    Howard            15278   42.391787                 17503
#                    Hutchinson         5000   23.391813                 15014
#                    Jim Wells         32949   80.617063                  7285
#                    Kenedy              310   74.340528                    87
#                    Kerr              13882   26.840681                 35760
#                    Kleberg           22660   72.889861                  6321
#                    Lamar              3899    7.862948                 36904
#                    Matagorda         15728   42.692725                 16149
#                    Maverick          55373   95.116463                  1607
#                    Moore             12230   55.346880                  7115
#                    Nacogdoches       12796   19.512046                 38932
#                    Navarro           13318   27.346461                 27386
#                    Nolan              5596   37.887610                  8150
#                    Palo Pinto         5677   19.870494                 21479
#                    Reeves            11502   75.269943                  2742
#                    Scurry             6919   40.580645                  9002
#                    Starr             62084   96.322959                  2131
#                    Titus             14242   43.283491                 14854
#                    Trinity            1429    9.742960                 11511
#                    Uvalde            19383   71.439628                  7200
#                    Val Verde         40513   82.335129                  7312
#                    Walker            13090   18.118901                 40699
#                    Washington         5720   16.322803                 22315
#                    Wharton           17377   41.405356                 18600
#                    Wilbarger          3744   29.332498                  7412
#                    Willacy           19050   88.259822                  1916
#                    Zapata            13526   94.442117                   707
#       Noncore      Bailey             4550   64.292779                  2328
#                    Baylor              471   13.152751                  2937
#                    Blanco             2286   19.662825                  8918
#                    Borden              131   19.465082                   520
#
#                                 % Non-Hispanic White  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson                59.126098
#                    Andrews                 40.238122
#                    Angelina                60.661694
#                    Bee                     31.204127
#                    Brown                   71.581741
#                    Calhoun                 42.407101
#                    Cherokee                60.520674
#                    Cooke                   75.322722
#                    Dawson                  35.339109
#                    Deaf Smith              24.723933
#                    Erath                   74.588387
#                    Gillespie               74.574045
#                    Glasscock               60.459941
#                    Gray                    63.243171
#                    Hale                    33.948556
#                    Harrison                63.339884
#                    Henderson               78.133327
#                    Hockley                 46.591303
#                    Hopkins                 73.306664
#                    Howard                  48.565483
#                    Hutchinson              70.240936
#                    Jim Wells               17.824374
#                    Kenedy                  20.863309
#                    Kerr                    69.141531
#                    Kleberg                 20.332604
#                    Lamar                   74.422732
#                    Matagorda               43.835505
#                    Maverick                 2.760410
#                    Moore                   32.198941
#                    Nacogdoches             59.365660
#                    Navarro                 56.232932
#                    Nolan                   55.179418
#                    Palo Pinto              75.180259
#                    Reeves                  17.943852
#                    Scurry                  52.797654
#                    Starr                    3.306234
#                    Titus                   45.143448
#                    Trinity                 78.482307
#                    Uvalde                  26.536931
#                    Val Verde               14.860278
#                    Walker                  56.334694
#                    Washington              63.678909
#                    Wharton                 44.319482
#                    Wilbarger               58.069571
#                    Willacy                  8.876946
#                    Zapata                   4.936461
#       Noncore      Bailey                  32.895295
#                    Baylor                  82.016197
#                    Blanco                  76.707380
#                    Borden                  77.265973
#
#                                 # Not Proficient in English  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson                            1488
#                    Andrews                             1184
#                    Angelina                            3650
#                    Bee                                  838
#                    Brown                                474
#                    Calhoun                             1058
#                    Cherokee                            2630
#                    Cooke                               1402
#                    Dawson                               643
#                    Deaf Smith                          1686
#                    Erath                               1266
#                    Gillespie                           1021
#                    Glasscock                            203
#                    Gray                                 993
#                    Hale                                1964
#                    Harrison                            1369
#                    Henderson                           1626
#                    Hockley                              980
#                    Hopkins                             1068
#                    Howard                              2427
#                    Hutchinson                           438
#                    Jim Wells                           1456
#                    Kenedy                               185
#                    Kerr                                1185
#                    Kleberg                              840
#                    Lamar                                533
#                    Matagorda                           2042
#                    Maverick                           14470
#                    Moore                               2891
#                    Nacogdoches                         2619
#                    Navarro                             2996
#                    Nolan                                450
#                    Palo Pinto                          1107
#                    Reeves                              2065
#                    Scurry                               532
#                    Starr                              17214
#                    Titus                               3109
#                    Trinity                              198
#                    Uvalde                              2118
#                    Val Verde                           6185
#                    Walker                              1696
#                    Washington                           815
#                    Wharton                             1864
#                    Wilbarger                            270
#                    Willacy                             2319
#                    Zapata                              3064
#       Noncore      Bailey                              1124
#                    Baylor                                 0
#                    Blanco                               288
#                    Borden                                 4
#
#                                 % Not Proficient in English   % Female  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson                        2.715874  39.067560
#                    Andrews                         7.408334  49.035098
#                    Angelina                        4.471560  51.333068
#                    Bee                             2.722282  39.323772
#                    Brown                           1.328736  50.582083
#                    Calhoun                         5.196208  48.896247
#                    Cherokee                        5.481222  48.968224
#                    Cooke                           3.848054  50.159168
#                    Dawson                          5.273518  45.469445
#                    Deaf Smith                      9.784123  50.180505
#                    Erath                           3.278689  50.899473
#                    Gillespie                       4.139133  51.583727
#                    Glasscock                      14.882698  45.326409
#                    Gray                            4.663285  46.612212
#                    Hale                            6.139227  48.110388
#                    Harrison                        2.199479  51.100344
#                    Henderson                       2.163068  51.203987
#                    Hockley                         4.522172  49.995669
#                    Hopkins                         3.181033  50.800088
#                    Howard                          7.106673  42.780244
#                    Hutchinson                      2.166815  49.726316
#                    Jim Wells                       3.826443  50.610457
#                    Kenedy                         35.305344  48.920863
#                    Kerr                            2.459833  51.836814
#                    Kleberg                         2.861133  48.941714
#                    Lamar                           1.155130  51.844233
#                    Matagorda                       5.978102  49.866992
#                    Maverick                       27.813551  50.121960
#                    Moore                          14.395976  48.006517
#                    Nacogdoches                     4.295767  52.110400
#                    Navarro                         6.690188  50.920926
#                    Nolan                           3.209929  50.155721
#                    Palo Pinto                      4.210086  50.752538
#                    Reeves                         14.889322  38.911066
#                    Scurry                          3.302912  46.093842
#                    Starr                          30.214842  51.326527
#                    Titus                          10.311090  50.854000
#                    Trinity                         1.432499  51.462467
#                    Uvalde                          8.510467  50.821908
#                    Val Verde                      13.812895  48.944213
#                    Walker                          2.505244  41.697003
#                    Washington                      2.492279  50.743372
#                    Wharton                         4.828890  50.898303
#                    Wilbarger                       2.208770  50.658101
#                    Willacy                        11.344291  44.597850
#                    Zapata                         23.625569  50.020947
#       Noncore      Bailey                         17.105463  49.780981
#                    Baylor                          0.000000  50.879643
#                    Blanco                          2.708294  50.180630
#                    Borden                          0.759013  47.994056
#
#                                 # Rural     % Rural
# URCS  URCS Name    County
# Rural Micropolitan Anderson       39204   67.063533
#                    Andrews         2440   16.502097
#                    Angelina       37383   43.082366
#                    Bee            13693   42.977308
#                    Brown          15395   40.400462
#                    Calhoun         9564   44.731303
#                    Cherokee       32057   63.048481
#                    Cooke          22691   59.034264
#                    Dawson          2254   16.294369
#                    Deaf Smith      3431   17.711129
#                    Erath          17551   46.320929
#                    Gillespie      13326   53.653823
#                    Glasscock       1226  100.000000
#                    Gray            4369   19.387619
#                    Hale            8379   23.099826
#                    Harrison       36789   56.054304
#                    Henderson      47206   60.110528
#                    Hockley         9139   39.847395
#                    Hopkins        20965   59.625722
#                    Howard          7025   20.064549
#                    Hutchinson      4998   22.564334
#                    Jim Wells      16370   40.085215
#                    Kenedy           416  100.000000
#                    Kerr           20397   41.102267
#                    Kleberg         6050   18.870279
#                    Lamar          23444   47.082923
#                    Matagorda      13366   36.417634
#                    Maverick        5022    9.255778
#                    Moore           3683   16.814280
#                    Nacogdoches    29978   46.460232
#                    Navarro        25136   52.657379
#                    Nolan           4969   32.656414
#                    Palo Pinto     14116   50.215218
#                    Reeves          1998   14.496118
#                    Scurry          5364   31.700254
#                    Starr          14453   23.705878
#                    Titus          16347   50.556690
#                    Trinity        11265   77.236887
#                    Uvalde          8287   31.384208
#                    Val Verde       4965   10.157736
#                    Walker         30933   45.582883
#                    Washington     18036   53.490717
#                    Wharton        20597   49.895833
#                    Wilbarger       2963   21.891393
#                    Willacy         7653   34.575766
#                    Zapata          3299   23.534028
#       Noncore      Bailey          2060   28.750872
#                    Baylor          3726  100.000000
#                    Blanco         10497  100.000000
#                    Borden           641  100.000000
#
# [50 rows x 158 columns]

# %%
rural_df = multi_df.loc['Rural']
print(rural_df.shape)
# Out:
# (172, 158)

# %%
urban_df = multi_df.loc['Urban']
print(urban_df.shape)
# Out:
# (82, 158)

# %%
corr1 = multi_df.corr()

# %%
corr1.to_csv('Corr1.csv')

# %%
multi_df.to_csv('multi_df.csv')

# %%
corr1_spear = multi_df.corr(method='spearman')

# %%
corr1_spear.to_csv('Corr1_spear.csv')

# %% [markdown]
# ## Function to easily do a panel of scatterplots easily

# %%
def makePanelScatterplot(data_df, x_data,y_data,color_col,split_col):
    x_label = x_data
    y_label = y_data
    ylim_min = data_df[y_data].min()*1.05
    ylim_max = data_df[y_data].max()*1.05
    xlim_min = data_df[x_data].min()*1.05
    xlim_max = data_df[x_data].max()*1.05

    g = sns.lmplot(x=x_data, y=y_data, data=data_df,\
           hue=color_col, col=split_col,col_wrap=3)

        
    g = (g.set_axis_labels(x_label, y_label)
          .set(ylim=(ylim_min, ylim_max),xlim=(xlim_min, xlim_max))
          .fig.subplots_adjust(wspace=.02))

# %% [markdown]
# ## Function to call OLS Regression Statsmodel from 2 columns of dataframe

# %%
def olsRegressionAnalysis (df,df_name,dep_col,ind_col):
    stat_dep_col = dep_col.replace(' ','_').replace('-','_').replace('(','_').replace(')','')
    stat_ind_col = ind_col.replace(' ','_').replace('-','_').replace('(','_').replace(')','')
    stat_col_list = [stat_dep_col,stat_ind_col]
    #print(f'stat_dep_col: {stat_dep_col}, stat_ind_col: {stat_ind_col}')
    col_list = [dep_col,ind_col]

    col_dict = {col_list[i]: stat_col_list[i] for i in range(len(col_list))} 
    #print(col_dict)
    stat_df = df[col_list].dropna()
    stat_df.rename(columns=col_dict,inplace=True)
    print(f'\u001b[34m{dep_col}\u001b[0m fitted against \u001b[34m{ind_col}\u001b[0m using \x1b[31m{df_name}\x1b[0m dataframe:\n')
    print(f'We have {stat_df.shape[0]} rows left after dropping Null values\n')
    model_string = stat_dep_col + " ~ " + stat_ind_col
    all_model = ols(model_string, data=stat_df).fit()
    print(all_model.summary())

# %% [markdown]
# ## Spot check for outliers for our dependent variable 'Age-Adjusted Mortality' (AAMR)

# %%
# Run a boxplot of the Urban vs.Rural AAMR
g = sns.boxplot(y='Age-Adjusted Mortality', x='URCS', 
                 data=all_df, 
                 palette="colorblind")
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'Urban'), Text(0, 0, 'Rural')]

# %%
g = sns.boxplot(y='Age-Adjusted Mortality', x='URCS Name', 
                 data=all_df, 
                 palette="colorblind")
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'Large central metro'),
#  Text(0, 0, 'Large fringe metro'),
#  Text(0, 0, 'Medium metro'),
#  Text(0, 0, 'Small metro'),
#  Text(0, 0, 'Micropolitan'),
#  Text(0, 0, 'Noncore')]

# %% [markdown]
# ## Clean each column of the dataframe for outliers in each column
#
# For each URCS Name we will make a dataframe and then act on each column to substitute a NaN value for the outlier.
# The cutoff for outliers will be set to a zscore of greater than 2 (So we keep the actual value where zscore < 2 in our mask)

# %%
# First cut the urban_df for the URCS Name value (shown in the box plot above)
lcm_df = urban_df.loc['Large central metro']
# Drop the non-numeric columns (they will throw an error if we try to calculate a zscore)
lcm_df = lcm_df.drop(["URCS description","PCP Ratio","Dentist Ratio",\
               "MHP Ratio","Presence of violation","Other PCP Ratio"], axis=1)
# Fill the NaN values with zeros - otherwise the zscore mask will replace all values in the column with NaN
lcm_df = lcm_df.fillna(0)
# Apply a condition to every column to replace any value with a zscore < 2 with NaN
lcm_df = lcm_df.where(lcm_df.apply(zscore).lt(2))
# Transform all the zero values back to NaN
lcm_df.replace(0, np.nan, inplace=True)
# Reset the Index to put the indexes back into columns 
lcm_df.reset_index(inplace=True)

# %%
# Repeat procedure for each value of the URCS Name value - see above cell comments for logic
lfm_df = urban_df.loc['Large fringe metro']
lfm_df = lfm_df.drop(["URCS description","PCP Ratio","Dentist Ratio",\
               "MHP Ratio","Presence of violation","Other PCP Ratio"], axis=1)
lfm_df = lfm_df.fillna(0)
lfm_df = lfm_df.where(lfm_df.apply(zscore).lt(2))
lfm_df.replace(0, np.nan, inplace=True)
lfm_df.reset_index(inplace=True)

# %%
# Repeat procedure for each value of the URCS Name value - see above cell comments for logic
mm_df = urban_df.loc['Medium metro']
mm_df = mm_df.drop(["URCS description","PCP Ratio","Dentist Ratio",\
               "MHP Ratio","Presence of violation","Other PCP Ratio"], axis=1)
mm_df = mm_df.fillna(0)
mm_df = mm_df.where(mm_df.apply(zscore).lt(2))
mm_df.replace(0, np.nan, inplace=True)
mm_df.reset_index(inplace=True)

# %%
# Repeat procedure for each value of the URCS Name value - see above cell comments for logic
sm_df = urban_df.loc['Small metro']
#sm_df['Age-Adjusted Mortality']
sm_df = sm_df.drop(["URCS description","PCP Ratio","Dentist Ratio",\
               "MHP Ratio","Presence of violation","Other PCP Ratio"], axis=1)
sm_df =sm_df.fillna(0)
sm_df = sm_df.where(sm_df.apply(zscore).lt(2))
sm_df[sm_df['Age-Adjusted Mortality'] < 300] = np.nan
sm_df.replace(0, np.nan, inplace=True)
sm_df.reset_index(inplace=True) 
#sm_df['Age-Adjusted Mortality']

# %%
# Repeat procedure for each value of the URCS Name value - see above cell comments for logic
mp_df = rural_df.loc['Micropolitan']
mp_df = mp_df.drop(["URCS description","PCP Ratio","Dentist Ratio",\
               "MHP Ratio","Presence of violation","Other PCP Ratio"], axis=1)
mp_df = mp_df.fillna(0.000001)
mp_df = mp_df.where(mp_df.apply(zscore).lt(2))
#mp_df = mp_df.where(mp_df.apply(zscore).gt(2))
mp_df.replace(0.000001, np.nan, inplace=True)
mp_df.reset_index(inplace=True)

# %%
# Repeat procedure for each value of the URCS Name value - see above cell comments for logic
nc_df = rural_df.loc['Noncore']
nc_df = nc_df.drop(["URCS description","PCP Ratio","Dentist Ratio",\
               "MHP Ratio","Presence of violation","Other PCP Ratio"], axis=1)
nc_df = nc_df.fillna(0)
nc_df = nc_df.where(nc_df.apply(zscore).abs().lt(2))
nc_df[nc_df['Age-Adjusted Mortality'] < 200] = np.nan
nc_df.replace(0, np.nan, inplace=True)
nc_df.reset_index(inplace=True) 
#nc_df['Age-Adjusted Mortality']

# %%
# Concatonate all the partial dataframes that have removed outliers relative to their URCS Name classification
clean_df = pd.concat([lcm_df, lfm_df, mm_df, sm_df, mp_df, nc_df])

# %%
# Merge the clean dataframe back with the urcs dataframe to add back the URCS columns
all_clean_df = pd.merge(urcs,clean_df, how='inner', on='FIPS')
print(all_clean_df.shape)
# Out:
# (251, 156)

# %%
# Set index to a multiindex again using 3 columns
multi_clean_df = all_clean_df.set_index(['URCS','URCS Name','County'])
multi_clean_df = multi_clean_df.sort_index()
print(multi_clean_df.shape)
# Out:
# (251, 153)

# %% [markdown]
# ## Regenerate clean urban_df and rural_df from multi_clean_df

# %%
rural_clean_df = multi_clean_df.loc['Rural']
print(rural_df.shape)
# Out:
# (172, 158)

# %%
urban_clean_df = multi_clean_df.loc['Urban']
print(urban_df.shape)
# Out:
# (82, 158)

# %% [markdown]
# ## Rerun Box plot to verify no outliers for our dependent variable 'Age-Adjusted Mortality'

# %%
g = sns.boxplot(y='Age-Adjusted Mortality', x='URCS', 
                 data=all_clean_df, 
                 palette="colorblind")
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'Urban'), Text(0, 0, 'Rural')]

# %% [markdown]
# # Is there a significant difference between Urban and Rural populations?

# %%
# Create a series of just the Urban,AAMR data and also Rural,AAMR
urban_aamr = multi_clean_df.loc['Urban','Age-Adjusted Mortality'].dropna()
rural_aamr = multi_clean_df.loc['Rural','Age-Adjusted Mortality'].dropna()

# Run a t-test between the urban and rural Age-Adjusted Mortality
stats.ttest_ind(urban_aamr, rural_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-4.731900084902864, pvalue=5.013491835981784e-06)

# %% [markdown]
# #### The pvalue is much greater than 0.05 so there is no statistically significant difference between Urban and Rural populations with respect to measuring AAMR
#
# So the question is: If we segment our Urban and Rural populations using the URCS Classification scheme will we see a difference among the subpopulations of Urban and Rural?

# %%
g = sns.boxplot(y='Age-Adjusted Mortality', x='URCS Name', 
                 data=all_clean_df, 
                 palette="colorblind")
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'Large central metro'),
#  Text(0, 0, 'Large fringe metro'),
#  Text(0, 0, 'Medium metro'),
#  Text(0, 0, 'Small metro'),
#  Text(0, 0, 'Micropolitan'),
#  Text(0, 0, 'Noncore')]

# %%
# Create a series of just the Urban,AAMR data and also Rural,AAMR for each group
lcm_aamr = urban_clean_df.loc['Large central metro','Age-Adjusted Mortality'].dropna()
lfm_aamr = urban_clean_df.loc['Large fringe metro','Age-Adjusted Mortality'].dropna()
mm_aamr = urban_clean_df.loc['Medium metro','Age-Adjusted Mortality'].dropna()
sm_aamr = urban_clean_df.loc['Small metro','Age-Adjusted Mortality'].dropna()
mp_aamr = rural_clean_df.loc['Micropolitan','Age-Adjusted Mortality'].dropna()
nc_aamr = rural_clean_df.loc['Noncore','Age-Adjusted Mortality'].dropna()

# %% [markdown]
# ## Test 'Large central metro' (lcm) area against both 'Micropolitan' (mp) and 'Noncore' (nc) rural areas using a t-test

# %%
# Run a t-test between the urban lcm and rural mp for Age-Adjusted Mortality
stats.ttest_ind(lcm_aamr, mp_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.17916727114997, pvalue=0.0013662029029729151)

# %%
# Run a t-test between the urban lcm and rural nc for Age-Adjusted Mortality
stats.ttest_ind(lcm_aamr, nc_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.360783209206877, pvalue=0.0015806648534332046)

# %% [markdown]
# ## Test 'Large central metro' (lcm) area against remaining 'Large fringe metro' (lfm), 'Medium metro' (mm) and 'Small metro' (sm) urban areas using a t-test

# %%
# Run a t-test between the urban lcm and urban lfm for Age-Adjusted Mortality
stats.ttest_ind(lcm_aamr, lfm_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.3423352117863, pvalue=0.21749505027772037)

# %%
# Run a t-test between the urban lcm and urban mm for Age-Adjusted Mortality
stats.ttest_ind(lcm_aamr, mm_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-3.6000176726999022, pvalue=0.004034765207805986)

# %%
# Run a t-test between the urban lcm and urban sm for Age-Adjusted Mortality
stats.ttest_ind(lcm_aamr, sm_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.418686036720096, pvalue=0.0012260087702403997)

# %% [markdown]
# ### The lcm urban area has a significantly better health outcome against both urban areas mm and sm but not against lfm
# The pvalues of 0.0040 and 0.0012 show a statistically significant better outcome for lcm vs. both mm and sm but
# the pvalue of 0.2175 does not show a statistically significant difference in health outcome as measured by AAMR

# %% [markdown]
# ## Test 'Large fringe metro' (lfm) area against both 'Micropolitan' (mp) and 'Noncore' (nc) rural areas using a t-test

# %%
# Run a t-test between the urban lfm and rural mp for Age-Adjusted Mortality
stats.ttest_ind(lfm_aamr, mp_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-6.299666267651455, pvalue=4.025405061713767e-08)

# %%
# Run a t-test between the urban lfm and rural nc for Age-Adjusted Mortality
stats.ttest_ind(lfm_aamr, nc_aamr, equal_var=False)
# Out:
# Ttest_indResult(statistic=-6.884982635586501, pvalue=6.538130703639622e-09)

# %% [markdown]
# ### The lfm urban area is NOT significantly better health outcome against both rural areas mp and nc
# The pvalues of 4.025 and 6.538 do not show a statistically significant better outcome for lcm vs. both mp and nc

# %%
olsRegressionAnalysis(urban_clean_df,"urban_clean_df","Age-Adjusted Mortality","Household Income")
# Out:
# Age-Adjusted Mortality fitted against Household Income using urban_clean_df dataframe:
#
# We have 76 rows left after dropping Null values
#
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Age_Adjusted_Mortality   R-squared:                       0.314
# Model:                                OLS   Adj. R-squared:                  0.305
# Method:                     Least Squares   F-statistic:                     33.92
# Date:                    Fri, 31 Jan 2020   Prob (F-statistic):           1.39e-07
# Time:                            13:59:31   Log-Likelihood:                -423.90
# No. Observations:                      76   AIC:                             851.8
# Df Residuals:                          74   BIC:                             856.5
# Df Model:                               1
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          581.1714     34.480     16.855      0.000     512.468     649.875
# Household_Income    -0.0035      0.001     -5.824      0.000      -0.005      -0.002
# ==============================================================================
# Omnibus:                        4.395   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.700
# Skew:                          -0.392   Prob(JB):                        0.157
# Kurtosis:                       3.745   Cond. No.                     2.69e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
urb_inc = multi_clean_df.loc['Urban','Age-Adjusted Mortality'].dropna()
urb_inc.describe()
# Out:
# count     79.000000
# mean     380.820253
# std       80.217795
# min      214.400000
# 25%      331.750000
# 50%      379.600000
# 75%      436.600000
# max      553.000000
# Name: Age-Adjusted Mortality, dtype: float64

# %%
print(stats.normaltest(urb_inc))
# Out:
# NormaltestResult(statistic=1.2353965267810523, pvalue=0.5391840701070203)

# %%
sns.jointplot(data=urban_clean_df, x="Household Income", y="Age-Adjusted Mortality", kind='reg', color='g')

# %% [markdown]
# # What factors correlate with AAMR?
#
# olsRegressionAnalysis(urban_clean_df,"urban_clean_df","Age-Adjusted Mortality","Household Income")
#
# urb_inc = multi_clean_df.loc['Urban','Age-Adjusted Mortality'].dropna()
# urb_inc.describe()
#
# print(stats.normaltest(urb_inc))
#
# sns.jointplot(data=urban_clean_df, x="Household Income", y="Age-Adjusted Mortality", kind='reg', color='g')

# %% [markdown]
# ## Age adjusted Mortality (Deaths/100k) for Everyone

# %%
makePanelScatterplot(all_clean_df,"Household Income","Age-Adjusted Mortality","URCS","URCS")

# %% [markdown]
# ## Statistically Examine the Urban AAMR vs.Household Income (HI)

# %%
olsRegressionAnalysis(urban_clean_df,"urban_clean_df","Age-Adjusted Mortality","Household Income")
# Out:
# Age-Adjusted Mortality fitted against Household Income using urban_clean_df dataframe:
#
# We have 76 rows left after dropping Null values
#
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Age_Adjusted_Mortality   R-squared:                       0.314
# Model:                                OLS   Adj. R-squared:                  0.305
# Method:                     Least Squares   F-statistic:                     33.92
# Date:                    Fri, 31 Jan 2020   Prob (F-statistic):           1.39e-07
# Time:                            13:59:31   Log-Likelihood:                -423.90
# No. Observations:                      76   AIC:                             851.8
# Df Residuals:                          74   BIC:                             856.5
# Df Model:                               1
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          581.1714     34.480     16.855      0.000     512.468     649.875
# Household_Income    -0.0035      0.001     -5.824      0.000      -0.005      -0.002
# ==============================================================================
# Omnibus:                        4.395   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.700
# Skew:                          -0.392   Prob(JB):                        0.157
# Kurtosis:                       3.745   Cond. No.                     2.69e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
urb_inc = multi_clean_df.loc['Urban','Age-Adjusted Mortality'].dropna()
urb_inc.describe()
# Out:
# count     79.000000
# mean     380.820253
# std       80.217795
# min      214.400000
# 25%      331.750000
# 50%      379.600000
# 75%      436.600000
# max      553.000000
# Name: Age-Adjusted Mortality, dtype: float64

# %%
print(stats.normaltest(urb_inc))
# Out:
# NormaltestResult(statistic=1.2353965267810523, pvalue=0.5391840701070203)

# %%
sns.distplot(urb_inc);

# %%
sns.jointplot(data=urban_clean_df, x="Household Income", y="Age-Adjusted Mortality", kind='reg', color='g')

# %%
olsRegressionAnalysis(urban_clean_df,"urban_clean_df","Age-Adjusted Mortality","Household Income")
# Out:
# Age-Adjusted Mortality fitted against Household Income using urban_clean_df dataframe:
#
# We have 76 rows left after dropping Null values
#
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Age_Adjusted_Mortality   R-squared:                       0.314
# Model:                                OLS   Adj. R-squared:                  0.305
# Method:                     Least Squares   F-statistic:                     33.92
# Date:                    Fri, 31 Jan 2020   Prob (F-statistic):           1.39e-07
# Time:                            13:59:31   Log-Likelihood:                -423.90
# No. Observations:                      76   AIC:                             851.8
# Df Residuals:                          74   BIC:                             856.5
# Df Model:                               1
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          581.1714     34.480     16.855      0.000     512.468     649.875
# Household_Income    -0.0035      0.001     -5.824      0.000      -0.005      -0.002
# ==============================================================================
# Omnibus:                        4.395   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.700
# Skew:                          -0.392   Prob(JB):                        0.157
# Kurtosis:                       3.745   Cond. No.                     2.69e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
urb_inc = multi_clean_df.loc['Urban','Age-Adjusted Mortality'].dropna()
urb_inc.describe()
# Out:
# count     79.000000
# mean     380.820253
# std       80.217795
# min      214.400000
# 25%      331.750000
# 50%      379.600000
# 75%      436.600000
# max      553.000000
# Name: Age-Adjusted Mortality, dtype: float64

# %%
print(stats.normaltest(urb_inc))
# Out:
# NormaltestResult(statistic=1.2353965267810523, pvalue=0.5391840701070203)

# %%
sns.jointplot(data=urban_clean_df, x="Household Income", y="Age-Adjusted Mortality", kind='reg', color='g')

# %%
makePanelScatterplot(all_df,"Household Income","Age-Adjusted Mortality","URCS","URCS")

# %%
olsRegressionAnalysis(urban_df,"urban_df","Age-Adjusted Mortality","Teen Birth Rate (White)")
# Out:
# Age-Adjusted Mortality fitted against Teen Birth Rate (White) using urban_df dataframe:
#
# We have 76 rows left after dropping Null values
#
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Age_Adjusted_Mortality   R-squared:                       0.633
# Model:                                OLS   Adj. R-squared:                  0.628
# Method:                     Least Squares   F-statistic:                     127.6
# Date:                    Fri, 31 Jan 2020   Prob (F-statistic):           9.03e-18
# Time:                            08:45:09   Log-Likelihood:                -401.77
# No. Observations:                      76   AIC:                             807.5
# Df Residuals:                          74   BIC:                             812.2
# Df Model:                               1
# Covariance Type:                nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                235.3171     14.085     16.707      0.000     207.252     263.382
# Teen_Birth_Rate__White     5.4074      0.479     11.297      0.000       4.454       6.361
# ==============================================================================
# Omnibus:                        7.553   Durbin-Watson:                   2.255
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.348
# Skew:                           0.573   Prob(JB):                       0.0254
# Kurtosis:                       4.004   Cond. No.                         74.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
olsRegressionAnalysis(rural_df,"rural_df","Age-Adjusted Mortality","Household Income")
# Out:
# Age-Adjusted Mortality fitted against Household Income using rural_df dataframe:
#
# We have 163 rows left after dropping Null values
#
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Age_Adjusted_Mortality   R-squared:                       0.098
# Model:                                OLS   Adj. R-squared:                  0.092
# Method:                     Least Squares   F-statistic:                     17.50
# Date:                    Thu, 30 Jan 2020   Prob (F-statistic):           4.71e-05
# Time:                            23:05:47   Log-Likelihood:                -952.33
# No. Observations:                     163   AIC:                             1909.
# Df Residuals:                         161   BIC:                             1915.
# Df Model:                               1
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          599.3677     40.106     14.945      0.000     520.167     678.568
# Household_Income    -0.0037      0.001     -4.183      0.000      -0.005      -0.002
# ==============================================================================
# Omnibus:                       22.465   Durbin-Watson:                   1.794
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               80.995
# Skew:                           0.379   Prob(JB):                     2.58e-18
# Kurtosis:                       6.369   Cond. No.                     2.75e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
makePanelScatterplot(all_clean_df,"Household Income","Age-Adjusted Mortality","URCS","URCS Name")

# %% [markdown]
# # Age adjusted Mortality (Deaths/100k) for Blacks

# %%
makePanelScatterplot(all_clean_df,"Household income (Black)","Age-Adjusted Mortality (Black)","URCS","URCS")

# %%
makePanelScatterplot(all_clean_df,"Household income (Black)","Age-Adjusted Mortality (Black)","URCS","URCS Name")

# %% [markdown]
# # Age adjusted Mortality (Deaths/100k) for Whites

# %%
makePanelScatterplot(all_clean_df,"Age-Adjusted Mortality (White)","Household income (White)","URCS","URCS")

# %%
data_df = multi_df
x_data = "Age-Adjusted Mortality (White)"
y_data = "Household income (White)"
color_col = "URCS"
split_col = "URCS Name"
x_label = x_data
y_label = y_data
ylim_min = data_df[y_data].min()*1.05
ylim_max = data_df[y_data].max()*1.05

g = sns.lmplot(x=x_data, y=y_data, data=all_df,\
           hue=color_col, col=split_col,col_wrap=3,height=4)

g = (g.set_axis_labels(x_label, y_label)
      .set(ylim=(ylim_min, ylim_max))
      .fig.subplots_adjust(wspace=.02))

# %% [markdown]
# # Age adjusted Mortality (Deaths/100k) for Hispanics

# %%
data_df = all_df
x_data = "Household income (Hispanic)"
y_data = "Age-Adjusted Mortality (Hispanic)"
color_col = "URCS"
split_col = "URCS"
x_label = x_data
y_label = y_data
ylim_min = data_df[y_data].min()*1.05
ylim_max = data_df[y_data].max()*1.05
print(f'ylim min:{ylim_min}, ylim max:{ylim_max}')
g = sns.lmplot(x=x_data, y=y_data, data=data_df,\
           hue=color_col, col=split_col)

g = (g.set_axis_labels(x_label, y_label)
      .set(ylim=(ylim_min, ylim_max))
      .fig.subplots_adjust(wspace=.02))
# Out:
# ylim min:143.4965179305, ylim max:641.7217326765001

# %%
data_df = all_df
x_data = "Household income (Hispanic)"
y_data = "Age-Adjusted Mortality (Hispanic)"
color_col = "URCS"
split_col = "URCS Name"
x_label = x_data
y_label = y_data
ylim_min = data_df[y_data].min()*1.05
ylim_max = data_df[y_data].max()*1.05
xlim_min = data_df[x_data].min()*1.05
xlim_max = data_df[x_data].max()*1.05

g = sns.lmplot(x=x_data, y=y_data, data=all_df,\
           hue=color_col, col=split_col,col_wrap=3,height=4)

g = (g.set_axis_labels(x_label, y_label)
      .set(ylim=(ylim_min, ylim_max),xlim=(xlim_min, xlim_max))
      .fig.subplots_adjust(wspace=.02))

# %%
lcm = multi_df.loc[['Rural'],'Age-Adjusted Mortality'].dropna()
lcm.describe()
# Out:
# count    163.000000
# mean     433.869325
# std       88.079829
# min      180.500000
# 25%      376.950000
# 50%      431.700000
# 75%      484.900000
# max      869.100000
# Name: Age-Adjusted Mortality, dtype: float64

# %%
sns.distplot(lcm);

# %%
print(stats.normaltest(lcm))
# Out:
# NormaltestResult(statistic=26.02512234602829, pvalue=2.2321145947837846e-06)

# %%
sns.jointplot(data=multi_clean_df, x='Age-Adjusted Mortality', y=y_data, kind='reg', color='g')

# %%
# View the columns that contain 'Black'
regex4 = '.*Black.*'
cols_black = [col for col in multi_df.columns if re.match(regex4,col) is not None] 
cols_black
# Out:
# ['YPLL Rate (Black)',
#  '% LBW (Black)',
#  'Teen Birth Rate (Black)',
#  'Preventable Hosp. Rate (Black)',
#  '% Screened (Black)',
#  '% Vaccinated (Black)',
#  '% Children in Poverty (Black)',
#  '% Drive Alone (Black)',
#  'Life Expectancy (Black)',
#  'Age-Adjusted Mortality (Black)',
#  'Child Mortality Rate (Black)',
#  'Infant Mortality Rate (Black)',
#  'Household income (Black)']

# %%
lcm
sns.boxplot(lcm)
# flierprops = dict(markerfacecolor='0.75', markersize=5,
#               linestyle='none')
# seaborn.boxplot(x="centrality", y="score", hue="model", data=data,
#                 flierprops=flierprops)

# %%
all_df.columns.values
# Out:
# array(['FIPS', 'URCS description', 'Years of Potential Life Lost Rate',
#        'YPLL Rate (Black)', 'YPLL Rate (Hispanic)', 'YPLL Rate (White)',
#        '% Fair/Poor', 'Physically Unhealthy Days',
#        'Mentally Unhealthy Days', '% LBW', '% LBW (Black)',
#        '% LBW (Hispanic)', '% LBW (White)', '% Smokers', '% Obese',
#        'Food Environment Index', '% Physically Inactive', '% With Access',
#        '% Excessive Drinking', '# Alcohol-Impaired Driving Deaths',
#        '# Driving Deaths', '% Alcohol-Impaired', '# Chlamydia Cases',
#        'Chlamydia Rate', 'Teen Birth Rate', 'Teen Birth Rate (Black)',
#        'Teen Birth Rate (Hispanic)', 'Teen Birth Rate (White)',
#        '# Uninsured', '% Uninsured', '# Primary Care Physicians',
#        'PCP Rate', 'PCP Ratio', '# Dentists', 'Dentist Rate',
#        'Dentist Ratio', '# Mental Health Providers', 'MHP Rate',
#        'MHP Ratio', 'Preventable Hosp. Rate',
#        'Preventable Hosp. Rate (Black)',
#        'Preventable Hosp. Rate (Hispanic)',
#        'Preventable Hosp. Rate (White)', '% Screened',
#        '% Screened (Black)', '% Screened (Hispanic)',
#        '% Screened (White)', '% Vaccinated', '% Vaccinated (Black)',
#        '% Vaccinated (Hispanic)', '% Vaccinated (White)', 'Cohort Size',
#        'Graduation Rate', '# Some College', 'Population',
#        '% Some College', '# Unemployed', 'Labor Force', '% Unemployed',
#        '% Children in Poverty', '% Children in Poverty (Black)',
#        '% Children in Poverty (Hispanic)',
#        '% Children in Poverty (White)', '80th Percentile Income',
#        '20th Percentile Income', 'Income Ratio',
#        '# Single-Parent Households', '# Households',
#        '% Single-Parent Households', '# Associations', 'Association Rate',
#        'Annual Average Violent Crimes', 'Violent Crime Rate',
#        '# Injury Deaths', 'Injury Death Rate', 'Average Daily PM2.5',
#        'Presence of violation', '% Severe Housing Problems',
#        'Severe Housing Cost Burden', 'Overcrowding',
#        'Inadequate Facilities', '% Drive Alone', '% Drive Alone (Black)',
#        '% Drive Alone (Hispanic)', '% Drive Alone (White)',
#        '# Workers who Drive Alone', '% Long Commute - Drives Alone',
#        'Life Expectancy', 'Life Expectancy (Black)',
#        'Life Expectancy (Hispanic)', 'Life Expectancy (White)',
#        '# Deaths', 'Age-Adjusted Mortality',
#        'Age-Adjusted Mortality (Black)',
#        'Age-Adjusted Mortality (Hispanic)',
#        'Age-Adjusted Mortality (White)', '# Deaths.1',
#        'Child Mortality Rate', 'Child Mortality Rate (Black)',
#        'Child Mortality Rate (Hispanic)', 'Child Mortality Rate (White)',
#        '# Deaths.2', 'Infant Mortality Rate',
#        'Infant Mortality Rate (Black)',
#        'Infant Mortality Rate (Hispanic)',
#        'Infant Mortality Rate (White)', '% Frequent Physical Distress',
#        '% Frequent Mental Distress', '% Diabetic', '# HIV Cases',
#        'HIV Prevalence Rate', '# Food Insecure', '% Food Insecure',
#        '# Limited Access', '% Limited Access', '# Drug Overdose Deaths',
#        'Drug Overdose Mortality Rate', '# Motor Vehicle Deaths',
#        'MV Mortality Rate', '% Insufficient Sleep', '# Uninsured.1',
#        '% Uninsured.1', 'Other PCP Rate', 'Other PCP Ratio',
#        '% Disconnected Youth', 'Household Income',
#        'Household income (Black)', 'Household income (Hispanic)',
#        'Household income (White)', '% Free or Reduced Lunch',
#        'Segregation index', 'Segregation Index', 'Homicide Rate',
#        '# Firearm Fatalities', 'Firearm Fatalities Rate', '# Homeowners',
#        '% Homeowners', '# Households with Severe Cost Burden',
#        '% Severe Housing Cost Burden', '% < 18', '% 65 and over',
#        '# African American', '% African American',
#        '# American Indian/Alaskan Native',
#        '% American Indian/Alaskan Native', '# Asian', '% Asian',
#        '# Native Hawaiian/Other Pacific Islander',
#        '% Native Hawaiian/Other Pacific Islander', '# Hispanic',
#        '% Hispanic', '# Non-Hispanic White', '% Non-Hispanic White',
#        '# Not Proficient in English', '% Not Proficient in English',
#        '% Female', '# Rural', '% Rural'], dtype=object)

# %%
indexes = [0,8,10,11]
for index in sorted(indexes, reverse=True):
    del cols_black[index]
cols_black
# Out:
# ['% LBW (Black)',
#  'Teen Birth Rate (Black)',
#  'Preventable Hosp. Rate (Black)',
#  '% Screened (Black)',
#  '% Vaccinated (Black)',
#  '% Children in Poverty (Black)',
#  '% Drive Alone (Black)',
#  'Age-Adjusted Mortality (Black)',
#  'Household income (Black)']

# %%
black_df = multi_df[cols_black]
black_df.columns
# Out:
# Index(['% LBW (Black)', 'Teen Birth Rate (Black)',
#        'Preventable Hosp. Rate (Black)', '% Screened (Black)',
#        '% Vaccinated (Black)', '% Children in Poverty (Black)',
#        '% Drive Alone (Black)', 'Age-Adjusted Mortality (Black)',
#        'Household income (Black)'],
#       dtype='object')

# %%
black_df.rename(columns={"% LBW (Black)" : "Low_Birth_Weight",
                   "Teen Birth Rate (Black)" : "Teen_Birth_Rate",
                   "Preventable Hosp. Rate (Black)"  : "Prev_Hosp_Rate",
                   "% Screened (Black)"  : "Mammography_Screen_Perct",
                   "% Vaccinated (Black)"  : "Vaccinated_Perct",
                   "% Children in Poverty (Black)"  : "Child_Poverty_Perct",
                   "% Drive Alone (Black)"  : "Drive_Alone_Perct",
                    "Age-Adjusted Mortality (Black)"  : "Age_Adj_Mortality_Rate",
                   "Household income (Black)"  : "Household_Income"     
                   }, inplace=True)
# Out:
# Index(['Low_Birth_Weight', 'Teen_Birth_Rate', 'Prev_Hosp_Rate',
#        'Mammography_Screen_Perct', 'Vaccinated_Perct', 'Child_Poverty_Perct',
#        'Drive_Alone_Perct', 'Age_Adj_Mortality_Rate', 'Household_Income'],
#       dtype='object')

# %%
black_df.head()
# Out:
#                              Low_Birth_Weight  Teen_Birth_Rate  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson         11.444921        46.068796
#                    Andrews                NaN              NaN
#                    Angelina         14.041605        47.093649
#                    Bee              22.222222              NaN
#                    Brown            12.962963        28.213166
#
#                              Prev_Hosp_Rate  Mammography_Screen_Perct  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson          8528.0                      38.0
#                    Andrews              NaN                       NaN
#                    Angelina          6249.0                      33.0
#                    Bee                  NaN                       NaN
#                    Brown              935.0                      45.0
#
#                              Vaccinated_Perct  Child_Poverty_Perct  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson              35.0            44.431349
#                    Andrews                NaN                  NaN
#                    Angelina              36.0            48.363742
#                    Bee                   17.0            53.658537
#                    Brown                 31.0            51.039261
#
#                              Drive_Alone_Perct  Age_Adj_Mortality_Rate  \
# URCS  URCS Name    County
# Rural Micropolitan Anderson          82.663714              721.905041
#                    Andrews                 NaN                     NaN
#                    Angelina          76.175099              676.504748
#                    Bee                     NaN                     NaN
#                    Brown                   NaN              656.572059
#
#                              Household_Income
# URCS  URCS Name    County
# Rural Micropolitan Anderson           24427.0
#                    Andrews            38359.0
#                    Angelina           28509.0
#                    Bee                41051.0
#                    Brown              33561.0

# %%
black_urban = black_df.loc['Urban']
black_rural = black_df.loc['Rural']
black_suburbs = black_urban.loc['Large fringe metro']
black_suburbs_clean = black_suburbs.dropna()
black_rural
# Out:
#                        Low_Birth_Weight  Teen_Birth_Rate  Prev_Hosp_Rate  \
# URCS Name    County
# Micropolitan Anderson         11.444921        46.068796          8528.0
#              Andrews                NaN              NaN             NaN
#              Angelina         14.041605        47.093649          6249.0
#              Bee              22.222222              NaN             NaN
#              Brown            12.962963        28.213166           935.0
# ...                                 ...              ...             ...
# Noncore      Winkler                NaN              NaN             NaN
#              Wood                   NaN        14.145811          5785.0
#              Yoakum                 NaN              NaN             NaN
#              Young                  NaN              NaN             NaN
#              Zavala                 NaN              NaN             NaN
#
#                        Mammography_Screen_Perct  Vaccinated_Perct  \
# URCS Name    County
# Micropolitan Anderson                      38.0              35.0
#              Andrews                        NaN               NaN
#              Angelina                      33.0              36.0
#              Bee                            NaN              17.0
#              Brown                         45.0              31.0
# ...                                         ...               ...
# Noncore      Winkler                        NaN               NaN
#              Wood                          44.0              33.0
#              Yoakum                         NaN               NaN
#              Young                          NaN              27.0
#              Zavala                         NaN               NaN
#
#                        Child_Poverty_Perct  Drive_Alone_Perct  \
# URCS Name    County
# Micropolitan Anderson            44.431349          82.663714
#              Andrews                   NaN                NaN
#              Angelina            48.363742          76.175099
#              Bee                 53.658537                NaN
#              Brown               51.039261                NaN
# ...                                    ...                ...
# Noncore      Winkler                   NaN                NaN
#              Wood                41.919192          68.656716
#              Yoakum                    NaN                NaN
#              Young               43.956044                NaN
#              Zavala                    NaN                NaN
#
#                        Age_Adj_Mortality_Rate  Household_Income
# URCS Name    County
# Micropolitan Anderson              721.905041           24427.0
#              Andrews                      NaN           38359.0
#              Angelina              676.504748           28509.0
#              Bee                          NaN           41051.0
#              Brown                 656.572059           33561.0
# ...                                       ...               ...
# Noncore      Winkler                      NaN               NaN
#              Wood                  559.535438           31277.0
#              Yoakum                       NaN               NaN
#              Young                        NaN               NaN
#              Zavala                       NaN               NaN
#
# [172 rows x 9 columns]

# %%
black_model = ols("Age_Adj_Mortality_Rate ~ Household_Income + Prev_Hosp_Rate + Child_Poverty_Perct + Vaccinated_Perct", data=black_rural).fit()
print(black_model.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Age_Adj_Mortality_Rate   R-squared:                       0.130
# Model:                                OLS   Adj. R-squared:                  0.050
# Method:                     Least Squares   F-statistic:                     1.638
# Date:                    Thu, 30 Jan 2020   Prob (F-statistic):              0.182
# Time:                            13:55:15   Log-Likelihood:                -302.83
# No. Observations:                      49   AIC:                             615.7
# Df Residuals:                          44   BIC:                             625.1
# Df Model:                               4
# Covariance Type:                nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             783.5211    170.375      4.599      0.000     440.153    1126.889
# Household_Income       -0.0025      0.004     -0.631      0.531      -0.010       0.005
# Prev_Hosp_Rate         -0.0164      0.007     -2.366      0.022      -0.030      -0.002
# Child_Poverty_Perct    -0.1515      1.328     -0.114      0.910      -2.828       2.525
# Vaccinated_Perct        1.2675      2.686      0.472      0.639      -4.147       6.682
# ==============================================================================
# Omnibus:                        0.677   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.713   Jarque-Bera (JB):                0.786
# Skew:                          -0.188   Prob(JB):                        0.675
# Kurtosis:                       2.506   Cond. No.                     2.81e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(black_model, fig=fig)

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.plot_partregress("Age_Adj_Mortality_Rate", "Household_Income", ["Teen_Birth_Rate", "Prev_Hosp_Rate", "Child_Poverty_Perct","Vaccinated_Perct"],  ax=ax, data=black_suburbs_clean)

# %%
# Out:
# Age-Adjusted Mortality fitted against Teen Birth Rate (White) using urban_df dataframe:
#
# We have 76 rows left after dropping Null values
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>
#
# NameError: name 'Teen_Birth_Rate_' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-436-e888c503b108> in <module>
# ----> 1 olsRegressionAnalysis(urban_df,"urban_df","Age-Adjusted Mortality","Teen Birth Rate (White)")
#
# <ipython-input-330-fc1b91dfabb8> in olsRegressionAnalysis(df, df_name, dep_col, ind_col)
#      13     print(f'We have {stat_df.shape[0]} rows left after dropping Null values\n')
#      14     model_string = stat_dep_col + " ~ " + stat_ind_col
# ---> 15     all_model = ols(model_string, data=stat_df).fit()
#      16     print(all_model.summary())
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     157
#     158         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 159                                   missing=missing)
#     160         ((endog, exog), missing_idx, design_info) = tmp
#     161
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# C:\ProgramData\Anaconda3\lib\site-packages\patsy\compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'Teen_Birth_Rate_' is not defined
#     Age_Adjusted_Mortality ~ Teen_Birth_Rate_(White)
#                              ^^^^^^^^^^^^^^^^^^^^^^^
