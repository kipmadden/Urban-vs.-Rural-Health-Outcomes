# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime
import os
import gmaps
import seaborn as sn
import re

# Import API key from a file that is ignored by Git (.gitignore file) so the key isn't exposed to the public
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %% [markdown]
# ## Store County Health Rankings Excel file results into DataFrame
#
# * Load the excel file imported from https://www.countyhealthrankings.org/app/texas/2019/measure/outcomes/144/description?sort=desc-2

# %%
path = "data/2019 County Health Rankings Texas Data - v1_0.xls"

# Get the available sheets in the excel file and put into a list
sheets = pd.ExcelFile(path).sheet_names
print(sheets)
# Out:
# ['Introduction', 'Outcomes & Factors Rankings', 'Outcomes & Factors SubRankings', 'Ranked Measure Data', 'Additional Measure Data', 'Ranked Measure Sources & Years', 'Addtl Measure Sources & Years']

# %% [markdown]
# ## Read in the Ranked Measure Data sheet eliminating columns and extra headers
# * Make a list of available columns to decide what we don't want
# * Formulate a regex expression to match unwanted columns
# * Create a list of only wanted columns to be used for the usecols argument
# * Set county to be the index
# * Eliminate any row without a county name

# %%
# Get the 'Ranked Measure Data' sheet using the sheets list above and rejecting the top header row
rmd = pd.read_excel(path, header=[1], sheet_name=sheets[3])

# View the columns and decide what we don't want
[print(col) for col in rmd.columns]
# Out:
# FIPS
# State
# County
# Years of Potential Life Lost Rate
# 95% CI - Low
# 95% CI - High
# Z-Score
# YPLL Rate (Black)
# YPLL Rate (Hispanic)
# YPLL Rate (White)
# % Fair/Poor
# 95% CI - Low.1
# 95% CI - High.1
# Z-Score.1
# Physically Unhealthy Days
# 95% CI - Low.2
# 95% CI - High.2
# Z-Score.2
# Mentally Unhealthy Days
# 95% CI - Low.3
# 95% CI - High.3
# Z-Score.3
# Unreliable
# % LBW
# 95% CI - Low.4
# 95% CI - High.4
# Z-Score.4
# % LBW (Black)
# % LBW (Hispanic)
# % LBW (White)
# % Smokers
# 95% CI - Low.5
# 95% CI - High.5
# Z-Score.5
# % Obese
# 95% CI - Low.6
# 95% CI - High.6
# Z-Score.6
# Food Environment Index
# Z-Score.7
# % Physically Inactive
# 95% CI - Low.7
# 95% CI - High.7
# Z-Score.8
# % With Access
# Z-Score.9
# % Excessive Drinking
# 95% CI - Low.8
# 95% CI - High.8
# Z-Score.10
# # Alcohol-Impaired Driving Deaths
# # Driving Deaths
# % Alcohol-Impaired
# 95% CI - Low.9
# 95% CI - High.9
# Z-Score.11
# # Chlamydia Cases
# Chlamydia Rate
# Z-Score.12
# Teen Birth Rate
# 95% CI - Low.10
# 95% CI - High.10
# Z-Score.13
# Teen Birth Rate (Black)
# Teen Birth Rate (Hispanic)
# Teen Birth Rate (White)
# # Uninsured
# % Uninsured
# 95% CI - Low.11
# 95% CI - High.11
# Z-Score.14
# # Primary Care Physicians
# PCP Rate
# PCP Ratio
# Z-Score.15
# # Dentists
# Dentist Rate
# Dentist Ratio
# Z-Score.16
# # Mental Health Providers
# MHP Rate
# MHP Ratio
# Z-Score.17
# Preventable Hosp. Rate
# Z-Score.18
# Preventable Hosp. Rate (Black)
# Preventable Hosp. Rate (Hispanic)
# Preventable Hosp. Rate (White)
# % Screened
# Z-Score.19
# % Screened (Black)
# % Screened (Hispanic)
# % Screened (White)
# % Vaccinated
# Z-Score.20
# % Vaccinated (Black)
# % Vaccinated (Hispanic)
# % Vaccinated (White)
# Cohort Size
# Graduation Rate
# Z-Score.21
# # Some College
# Population
# % Some College
# 95% CI - Low.12
# 95% CI - High.12
# Z-Score.22
# # Unemployed
# Labor Force
# % Unemployed
# Z-Score.23
# % Children in Poverty
# 95% CI - Low.13
# 95% CI - High.13
# Z-Score.24
# % Children in Poverty (Black)
# % Children in Poverty (Hispanic)
# % Children in Poverty (White)
# 80th Percentile Income
# 20th Percentile Income
# Income Ratio
# Z-Score.25
# # Single-Parent Households
# # Households
# % Single-Parent Households
# 95% CI - Low.14
# 95% CI - High.14
# Z-Score.26
# # Associations
# Association Rate
# Z-Score.27
# Annual Average Violent Crimes
# Violent Crime Rate
# Z-Score.28
# # Injury Deaths
# Injury Death Rate
# 95% CI - Low.15
# 95% CI - High.15
# Z-Score.29
# Average Daily PM2.5
# Z-Score.30
# Presence of violation
# Z-Score.31
# % Severe Housing Problems
# 95% CI - Low.16
# 95% CI - High.16
# Severe Housing Cost Burden
# Overcrowding
# Inadequate Facilities
# Z-Score.32
# % Drive Alone
# 95% CI - Low.17
# 95% CI - High.17
# Z-Score.33
# % Drive Alone (Black)
# % Drive Alone (Hispanic)
# % Drive Alone (White)
# # Workers who Drive Alone
# % Long Commute - Drives Alone
# 95% CI - Low.18
# 95% CI - High.18
# Z-Score.34
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Create a regular expression to match unwanted columns
regex = '^Z|95|FIPS|State|Unreliable'

# Use a list comprehension to make a list of columns that don't match the regex (a failed regex match returns 'None')
cols = [col for col in rmd.columns if re.match(regex,col) is None]

# Create a dataframe of the desired columns and set 'County' to the index
rmd_df = pd.read_excel(path, header=[1], sheet_name=sheets[3],usecols=cols,index_col=0)

# Drop any row that has Nan as an index value
rmd_df = rmd_df.loc[rmd_df.index.dropna()]
print(f'shape of rmd_df: {rmd_df.shape}')
#rmd_df.head(1)
# Out:
# shape of rmd_df: (254, 85)

# %% [markdown]
# ## Read in the Additional Measure Data sheet eliminating columns and extra headers
# * Make a list of available columns to decide what we don't want
# * Formulate a regex expression to match unwanted columns
# * Create a list of only wanted columns to be used for the usecols argument
# * Set county to be the index
# * Eliminate any row without a county name

# %%
# Get the 'Ranked Measure Data' sheet using the sheets list above and rejecting the top header row
amd = pd.read_excel(path, header=[1], sheet_name=sheets[4])

# View the columns and decide what we don't want
[print(col) for col in amd.columns]
# Out:
# FIPS
# State
# County
# Life Expectancy
# 95% CI - Low
# 95% CI - High
# Life Expectancy (Black)
# Life Expectancy (Hispanic)
# Life Expectancy (White)
# # Deaths
# Age-Adjusted Mortality
# 95% CI - Low.1
# 95% CI - High.1
# Age-Adjusted Mortality (Black)
# Age-Adjusted Mortality (Hispanic)
# Age-Adjusted Mortality (White)
# # Deaths.1
# Child Mortality Rate
# 95% CI - Low.2
# 95% CI - High.2
# Child Mortality Rate (Black)
# Child Mortality Rate (Hispanic)
# Child Mortality Rate (White)
# # Deaths.2
# Infant Mortality Rate
# 95% CI - Low.3
# 95% CI - High.3
# Infant Mortality Rate (Black)
# Infant Mortality Rate (Hispanic)
# Infant Mortality Rate (White)
# % Frequent Physical Distress
# 95% CI - Low.4
# 95% CI - High.4
# % Frequent Mental Distress
# 95% CI - Low.5
# 95% CI - High.5
# % Diabetic
# 95% CI - Low.6
# 95% CI - High.6
# # HIV Cases
# HIV Prevalence Rate
# # Food Insecure
# % Food Insecure
# # Limited Access
# % Limited Access
# # Drug Overdose Deaths
# Drug Overdose Mortality Rate
# # Motor Vehicle Deaths
# MV Mortality Rate
# 95% CI - Low.7
# 95% CI - High.7
# % Insufficient Sleep
# 95% CI - Low.8
# 95% CI - High.8
# # Uninsured
# % Uninsured
# 95% CI - Low.9
# 95% CI - High.9
# # Uninsured.1
# % Uninsured.1
# 95% CI - Low.10
# 95% CI - High.10
# Other PCP Rate
# Other PCP Ratio
# % Disconnected Youth
# Household Income
# 95% CI - Low.11
# 95% CI - High.11
# Household income (Black)
# Household income (Hispanic)
# Household income (White)
# % Free or Reduced Lunch
# Segregation index
# Segregation Index
# Homicide Rate
# 95% CI - Low.12
# 95% CI - High.12
# # Firearm Fatalities
# Firearm Fatalities Rate
# 95% CI - Low.13
# 95% CI - High.13
# # Homeowners
# % Homeowners
# 95% CI - Low.14
# 95% CI - High.14
# # Households with Severe Cost Burden
# % Severe Housing Cost Burden
# 95% CI - Low.15
# 95% CI - High.15
# Population
# % < 18
# % 65 and over
# # African American
# % African American
# # American Indian/Alaskan Native
# % American Indian/Alaskan Native
# # Asian
# % Asian
# # Native Hawaiian/Other Pacific Islander
# % Native Hawaiian/Other Pacific Islander
# # Hispanic
# % Hispanic
# # Non-Hispanic White
# % Non-Hispanic White
# # Not Proficient in English
# % Not Proficient in English
# 95% CI - Low.16
# 95% CI - High.16
# % Female
# # Rural
# % Rural
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Create a regular expression to match unwanted columns
regex = '^Z|95|FIPS|State|Unreliable'

# Use a list comprehension to make a list of columns that don't match the regex (a failed regex match returns 'None')
cols = [col for col in amd.columns if re.match(regex,col) is None]

# Create a dataframe of the desired columns and set 'County' to the index
amd_df = pd.read_excel(path, header=[1], sheet_name=sheets[4],usecols=cols,index_col=0)

# Drop any row that has Nan as an index value
amd_df = amd_df.loc[amd_df.index.dropna()]
print(f'shape of amd_df: {amd_df.shape}')
#amd_df.head(1)
# Out:
# shape of amd_df: (254, 74)

# %%
# Merge the rmd and amd dataframes using inner join on County column (index)
merged_df = pd.merge(rmd_df,amd_df, how='inner', on='County')
print(f'shape of merged_df: {merged_df.shape}')
#merged_df.head(1)
# Out:
# shape of merged_df: (254, 159)

# %%
# View the columns that end in '_x' or '_y'
regex2 = '.*_x$|.*_y$'
[print(col) for col in merged_df.columns if re.match(regex2,col) is not None]
# Out:
# # Uninsured_x
# % Uninsured_x
# Population_x
# # Uninsured_y
# % Uninsured_y
# Population_y
# [None, None, None, None, None, None]

# %%
# Drop the duplicate _y columns
regex3 = '.*_y$'
merged_df.drop([col for col in merged_df.columns if re.match(regex3,col) is not None],axis=1, inplace=True)
print(merged_df.shape)
# Out:
# (254, 156)

# %% [markdown]
# ## Import a County Status excel file (Maps counties to either 'Rural' or 'Urban')

# %%
path2 = 'data/county_status.xlsx'

# Get the available sheets in the excel file and put into a list
sheets2 = pd.ExcelFile(path2).sheet_names
print(sheets2)
# Out:
# ['RVU']

# %%
# Get the 'Ranked Measure Data' sheet using the sheets list above and rejecting the top header row
cs = pd.read_excel(path2,usecols=['County','Status'],index_col=0)
cs.index

# Drop any row that has Nan as an index value
cs = cs.loc[cs.index.dropna()]
print(f'shape of cs: {cs.shape}')
# Out:
# shape of cs: (258, 1)

# %%
# Check that all counties are in both lists and spelled the same 
print(f'merged_df county:{[county for county in merged_df.index if county not in cs.index]} not found in cs.index')
print(f'cs county:{[county for county in cs.index if county not in merged_df.index]} not found in merged_df.index')
# Out:
# merged_df county:['DeWitt'] not found in cs.index
# cs county:['De Witt', ' ', ' ', ' ', ' '] not found in merged_df.index

# %%
# Drop the columns with spaces as an index value
cs.loc[cs.index != ' ']
print(f'shape of cs: {cs.shape}')
# Out:
# shape of cs: (254, 1)

# %%
# Rename the cs index 'De Witt' to 'DeWitt'
cs = cs.rename(index={'De Witt': 'DeWitt'})
print(cs[cs.index == 'DeWitt'])
# Out:
#        Status
# County
# DeWitt  Rural

# %%
print(cs[cs.index == 'DeWitt'])
# Out:
#        Status
# County
# DeWitt  Rural

# %%
final_merged_df = pd.merge(cs,merged_df, how='inner', on='County')
print(final_merged_df.shape)
# Out:
# (254, 157)

# %%
final_merged_df.set_index('Status', append=True, inplace=True)
final_merged_df.head()
# Out:
#                  Years of Potential Life Lost Rate  YPLL Rate (Black)  \
# County   Status
# Anderson Rural                        10272.949118       12962.159784
# Andrews  Rural                         7952.973251                NaN
# Angelina Rural                         9018.498513       14014.161619
# Aransas  Urban                         9315.870361                NaN
# Archer   Urban                         9446.113949                NaN
#
#                  YPLL Rate (Hispanic)  YPLL Rate (White)  % Fair/Poor  \
# County   Status
# Anderson Rural           10880.315229        9971.540573    19.529585
# Andrews  Rural            7774.144329        8202.896838    17.307710
# Angelina Rural            4450.704830        9293.129659    23.207340
# Aransas  Urban            6088.571549       11277.610901    19.517678
# Archer   Urban                    NaN                NaN    13.248280
#
#                  Physically Unhealthy Days  Mentally Unhealthy Days     % LBW  \
# County   Status
# Anderson Rural                    3.926130                 3.642847  7.249879
# Andrews  Rural                    3.302811                 3.198057  6.313835
# Angelina Rural                    4.223947                 4.070546  8.769194
# Aransas  Urban                    3.859044                 3.743100  9.686610
# Archer   Urban                    3.194982                 3.405329  8.349146
#
#                  % LBW (Black)  % LBW (Hispanic)  ...  \
# County   Status                                   ...
# Anderson Rural       11.444921          4.428424  ...
# Andrews  Rural             NaN          5.912040  ...
# Angelina Rural       14.041605          8.052833  ...
# Aransas  Urban             NaN          8.623088  ...
# Archer   Urban             NaN               NaN  ...
#
#                  % Native Hawaiian/Other Pacific Islander  # Hispanic  \
# County   Status
# Anderson Rural                                   0.143745       10287
# Andrews  Rural                                   0.022571        9958
# Angelina Rural                                   0.063778       19475
# Aransas  Urban                                   0.082121        7072
# Archer   Urban                                   0.034056         765
#
#                  % Hispanic  # Non-Hispanic White  % Non-Hispanic White  \
# County   Status
# Anderson Rural    17.815763                 34140             59.126098
# Andrews  Rural    56.190046                  7131             40.238122
# Angelina Rural    22.179830                 53264             60.661694
# Aransas  Urban    27.655248                 17177             67.171125
# Archer   Urban     8.684300                  7754             88.023612
#
#                  # Not Proficient in English  % Not Proficient in English  \
# County   Status
# Anderson Rural                          1488                     2.715874
# Andrews  Rural                          1184                     7.408334
# Angelina Rural                          3650                     4.471560
# Aransas  Urban                           375                     1.588916
# Archer   Urban                            69                     0.823881
#
#                   % Female  # Rural    % Rural
# County   Status
# Anderson Rural   39.067560    39204  67.063533
# Andrews  Rural   49.035098     2440  16.502097
# Angelina Rural   51.333068    37383  43.082366
# Aransas  Urban   50.527921     6313  27.260558
# Archer   Urban   50.448405     8057  88.988292
#
# [5 rows x 156 columns]

# %%
final_merged_df = final_merged_df.reorder_levels([1,0]).sort_index()
#final_merged_df = final_merged_df.reindex()
final_merged_df.head()
# Out:
#                  Years of Potential Life Lost Rate  YPLL Rate (Black)  \
# Status County
# Rural  Anderson                       10272.949118       12962.159784
#        Andrews                         7952.973251                NaN
#        Angelina                        9018.498513       14014.161619
#        Bailey                          8326.013329                NaN
#        Baylor                         10617.916861                NaN
#
#                  YPLL Rate (Hispanic)  YPLL Rate (White)  % Fair/Poor  \
# Status County
# Rural  Anderson          10880.315229        9971.540573    19.529585
#        Andrews            7774.144329        8202.896838    17.307710
#        Angelina           4450.704830        9293.129659    23.207340
#        Bailey             7370.998705       12900.396823    27.307111
#        Baylor                     NaN                NaN    16.437425
#
#                  Physically Unhealthy Days  Mentally Unhealthy Days  \
# Status County
# Rural  Anderson                   3.926130                 3.642847
#        Andrews                    3.302811                 3.198057
#        Angelina                   4.223947                 4.070546
#        Bailey                     4.516392                 3.968838
#        Baylor                     3.682539                 3.731401
#
#                      % LBW  % LBW (Black)  % LBW (Hispanic)  ...  \
# Status County                                                ...
# Rural  Anderson   7.249879      11.444921          4.428424  ...
#        Andrews    6.313835            NaN          5.912040  ...
#        Angelina   8.769194      14.041605          8.052833  ...
#        Bailey     7.198228            NaN          7.973422  ...
#        Baylor    10.408922            NaN               NaN  ...
#
#                  % Native Hawaiian/Other Pacific Islander  # Hispanic  \
# Status County
# Rural  Anderson                                  0.143745       10287
#        Andrews                                   0.022571        9958
#        Angelina                                  0.063778       19475
#        Bailey                                    0.127173        4550
#        Baylor                                    0.083775         471
#
#                  % Hispanic  # Non-Hispanic White  % Non-Hispanic White  \
# Status County
# Rural  Anderson   17.815763                 34140             59.126098
#        Andrews    56.190046                  7131             40.238122
#        Angelina   22.179830                 53264             60.661694
#        Bailey     64.292779                  2328             32.895295
#        Baylor     13.152751                  2937             82.016197
#
#                  # Not Proficient in English  % Not Proficient in English  \
# Status County
# Rural  Anderson                         1488                     2.715874
#        Andrews                          1184                     7.408334
#        Angelina                         3650                     4.471560
#        Bailey                           1124                    17.105463
#        Baylor                              0                     0.000000
#
#                   % Female  # Rural     % Rural
# Status County
# Rural  Anderson  39.067560    39204   67.063533
#        Andrews   49.035098     2440   16.502097
#        Angelina  51.333068    37383   43.082366
#        Bailey    49.780981     2060   28.750872
#        Baylor    50.879643     3726  100.000000
#
# [5 rows x 156 columns]

# %%
final_merged_df.loc['Urban']
# Out:
#             Years of Potential Life Lost Rate  YPLL Rate (Black)  \
# County
# Aransas                           9315.870361                NaN
# Archer                            9446.113949                NaN
# Armstrong                                 NaN                NaN
# Atascosa                          7645.013715                NaN
# Austin                            6980.706882       10025.025387
# ...                                       ...                ...
# Webb                              6188.665833                NaN
# Wichita                           8861.946922       11885.873255
# Williamson                        4566.522045        6334.100003
# Wilson                            6649.458091                NaN
# Wise                              8305.397180                NaN
#
#             YPLL Rate (Hispanic)  YPLL Rate (White)  % Fair/Poor  \
# County
# Aransas              6088.571549       11277.610901    19.517678
# Archer                       NaN                NaN    13.248280
# Armstrong                    NaN                NaN    11.754162
# Atascosa             7306.194334        8273.952313    22.392609
# Austin               4244.328056        7927.523024    16.912532
# ...                          ...                ...          ...
# Webb                 6259.303047        4100.685260    35.918795
# Wichita              6518.579775        9023.173962    20.950828
# Williamson           3528.306621        5051.312047    12.909131
# Wilson               5852.679976        6968.865763    16.480516
# Wise                 6702.479753        8698.703618    15.514383
#
#             Physically Unhealthy Days  Mentally Unhealthy Days     % LBW  \
# County
# Aransas                      3.859044                 3.743100  9.686610
# Archer                       3.194982                 3.405329  8.349146
# Armstrong                    2.960202                 3.277977  8.108108
# Atascosa                     3.950304                 3.545031  8.163698
# Austin                       3.428932                 3.567402  7.929883
# ...                               ...                      ...       ...
# Webb                         5.048667                 4.083129  8.144736
# Wichita                      3.988507                 4.149413  8.184878
# Williamson                   2.983381                 3.091787  7.484833
# Wilson                       3.451917                 3.375382  7.251172
# Wise                         3.442757                 3.545164  6.425255
#
#             % LBW (Black)  % LBW (Hispanic)  ...  \
# County                                       ...
# Aransas               NaN          8.623088  ...
# Archer                NaN               NaN  ...
# Armstrong             NaN               NaN  ...
# Atascosa              NaN          8.549383  ...
# Austin          14.403292          7.049892  ...
# ...                   ...               ...  ...
# Webb                  NaN          8.133458  ...
# Wichita         11.261261          8.158996  ...
# Williamson      12.342007          7.170336  ...
# Wilson                NaN          8.466667  ...
# Wise                  NaN          5.944056  ...
#
#             % Native Hawaiian/Other Pacific Islander  # Hispanic  % Hispanic  \
# County
# Aransas                                     0.082121        7072   27.655248
# Archer                                      0.034056         765    8.684300
# Armstrong                                   0.000000         141    7.503991
# Atascosa                                    0.118413       31578   64.469896
# Austin                                      0.040287        8083   27.136910
# ...                                              ...         ...         ...
# Webb                                        0.053131      262489   95.522100
# Wichita                                     0.134848       25299   19.165909
# Williamson                                  0.156882      134252   24.518898
# Wilson                                      0.060847       19621   39.795960
# Wise                                        0.080083       12898   19.488977
#
#             # Non-Hispanic White  % Non-Hispanic White  \
# County
# Aransas                    17177             67.171125
# Archer                      7754             88.023612
# Armstrong                   1684             89.622139
# Atascosa                   16349             33.378249
# Austin                     18469             62.005640
# ...                          ...                   ...
# Webb                        9641              3.508446
# Wichita                    86207             65.308333
# Williamson                326435             59.617931
# Wilson                     28178             57.151550
# Wise                       50638             76.514407
#
#             # Not Proficient in English  % Not Proficient in English  \
# County
# Aransas                             375                     1.588916
# Archer                               69                     0.823881
# Armstrong                            11                     0.602410
# Atascosa                           1659                     3.712074
# Austin                             1415                     5.144145
# ...                                 ...                          ...
# Webb                              52845                    21.753090
# Wichita                            2684                     2.179421
# Williamson                        14171                     2.991171
# Wilson                             1343                     3.021780
# Wise                               1470                     2.490808
#
#              % Female  # Rural     % Rural
# County
# Aransas     50.527921     6313   27.260558
# Archer      50.448405     8057   88.988292
# Armstrong   51.250665     1901  100.000000
# Atascosa    50.186807    27266   60.711184
# Austin      50.399517    18853   66.344090
# ...               ...      ...         ...
# Webb        50.914867     6507    2.599639
# Wichita     48.188636    14027   10.666920
# Williamson  50.727885    50679   11.989950
# Wilson      49.809346    36850   85.861410
# Wise        49.834545    42635   72.107497
#
# [82 rows x 156 columns]

# %%
#idx = pd.IndexSlice
#rural_df = final_merged_df.loc[idx['Rural',:],:]
rural_df = final_merged_df.loc['Rural']
print(rural_df.shape)
# Out:
# (172, 156)

# %%
#urban_df = final_merged_df.loc[idx['Urban',:],:]
urban_df = final_merged_df.loc['Urban']
print(urban_df.shape)
# Out:
# (82, 156)

# %%
urban_df
# Out:
#             Years of Potential Life Lost Rate  YPLL Rate (Black)  \
# County
# Aransas                           9315.870361                NaN
# Archer                            9446.113949                NaN
# Armstrong                                 NaN                NaN
# Atascosa                          7645.013715                NaN
# Austin                            6980.706882       10025.025387
# ...                                       ...                ...
# Webb                              6188.665833                NaN
# Wichita                           8861.946922       11885.873255
# Williamson                        4566.522045        6334.100003
# Wilson                            6649.458091                NaN
# Wise                              8305.397180                NaN
#
#             YPLL Rate (Hispanic)  YPLL Rate (White)  % Fair/Poor  \
# County
# Aransas              6088.571549       11277.610901    19.517678
# Archer                       NaN                NaN    13.248280
# Armstrong                    NaN                NaN    11.754162
# Atascosa             7306.194334        8273.952313    22.392609
# Austin               4244.328056        7927.523024    16.912532
# ...                          ...                ...          ...
# Webb                 6259.303047        4100.685260    35.918795
# Wichita              6518.579775        9023.173962    20.950828
# Williamson           3528.306621        5051.312047    12.909131
# Wilson               5852.679976        6968.865763    16.480516
# Wise                 6702.479753        8698.703618    15.514383
#
#             Physically Unhealthy Days  Mentally Unhealthy Days     % LBW  \
# County
# Aransas                      3.859044                 3.743100  9.686610
# Archer                       3.194982                 3.405329  8.349146
# Armstrong                    2.960202                 3.277977  8.108108
# Atascosa                     3.950304                 3.545031  8.163698
# Austin                       3.428932                 3.567402  7.929883
# ...                               ...                      ...       ...
# Webb                         5.048667                 4.083129  8.144736
# Wichita                      3.988507                 4.149413  8.184878
# Williamson                   2.983381                 3.091787  7.484833
# Wilson                       3.451917                 3.375382  7.251172
# Wise                         3.442757                 3.545164  6.425255
#
#             % LBW (Black)  % LBW (Hispanic)  ...  \
# County                                       ...
# Aransas               NaN          8.623088  ...
# Archer                NaN               NaN  ...
# Armstrong             NaN               NaN  ...
# Atascosa              NaN          8.549383  ...
# Austin          14.403292          7.049892  ...
# ...                   ...               ...  ...
# Webb                  NaN          8.133458  ...
# Wichita         11.261261          8.158996  ...
# Williamson      12.342007          7.170336  ...
# Wilson                NaN          8.466667  ...
# Wise                  NaN          5.944056  ...
#
#             % Native Hawaiian/Other Pacific Islander  # Hispanic  % Hispanic  \
# County
# Aransas                                     0.082121        7072   27.655248
# Archer                                      0.034056         765    8.684300
# Armstrong                                   0.000000         141    7.503991
# Atascosa                                    0.118413       31578   64.469896
# Austin                                      0.040287        8083   27.136910
# ...                                              ...         ...         ...
# Webb                                        0.053131      262489   95.522100
# Wichita                                     0.134848       25299   19.165909
# Williamson                                  0.156882      134252   24.518898
# Wilson                                      0.060847       19621   39.795960
# Wise                                        0.080083       12898   19.488977
#
#             # Non-Hispanic White  % Non-Hispanic White  \
# County
# Aransas                    17177             67.171125
# Archer                      7754             88.023612
# Armstrong                   1684             89.622139
# Atascosa                   16349             33.378249
# Austin                     18469             62.005640
# ...                          ...                   ...
# Webb                        9641              3.508446
# Wichita                    86207             65.308333
# Williamson                326435             59.617931
# Wilson                     28178             57.151550
# Wise                       50638             76.514407
#
#             # Not Proficient in English  % Not Proficient in English  \
# County
# Aransas                             375                     1.588916
# Archer                               69                     0.823881
# Armstrong                            11                     0.602410
# Atascosa                           1659                     3.712074
# Austin                             1415                     5.144145
# ...                                 ...                          ...
# Webb                              52845                    21.753090
# Wichita                            2684                     2.179421
# Williamson                        14171                     2.991171
# Wilson                             1343                     3.021780
# Wise                               1470                     2.490808
#
#              % Female  # Rural     % Rural
# County
# Aransas     50.527921     6313   27.260558
# Archer      50.448405     8057   88.988292
# Armstrong   51.250665     1901  100.000000
# Atascosa    50.186807    27266   60.711184
# Austin      50.399517    18853   66.344090
# ...               ...      ...         ...
# Webb        50.914867     6507    2.599639
# Wichita     48.188636    14027   10.666920
# Williamson  50.727885    50679   11.989950
# Wilson      49.809346    36850   85.861410
# Wise        49.834545    42635   72.107497
#
# [82 rows x 156 columns]
